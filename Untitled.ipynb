# %%
from rocketapi import ThreadsAPI

threads_api = ThreadsAPI(token="KhlzoC4_b13TBx24ACy66g")
t1=threads_api.get_user_feed(314216)

# %%
t1['threads'][0]['thread_items'][0]['post']['caption']['text']
# Out:
# 'Get excited -- search is coming to Threads.'

# %%
t1['threads'][1]['thread_items'][0]['post']['caption']['text']
# Out:
# 'Actual footage of me building Threads for web. Rolling out over the next few days.'

# %%
for item in t1['threads']:
    print (item['thread_items'][0]['post']['caption']['text'])
# Out:
# Get excited -- search is coming to Threads.
# Actual footage of me building Threads for web. Rolling out over the next few days.
# Our little girl is growing up and wake surfing without a rope 😭
# Work hard, sleep hard 😴
# Congrats to our team!
# I think we can all agree Elon isn't serious and it's time to move on. I offered a real date. Dana White offered to make this a legit competition for charity. Elon won't confirm a date, then says he needs surgery, and now asks to do a practice round in my backyard instead. If Elon ever gets serious about a real date and official event, he knows how to reach me. Otherwise, time to move on. I'm going to focus on competing with people who take the sport seriously.
# Separately, here's a photo from today's Friday Morning Fights in my backyard octagon. Good times.
# ...

# %%
t1
# Out:
# {'medias': [],
#  'threads': [{'thread_items': [{'post': {'pk': 3181488185455460300,
#       'id': '3181488185455460300_314216',
#       'taken_at': 1693482973,
#       'device_timestamp': 52005099003962,
#       'client_cache_key': 'MzE4MTQ4ODE4NTQ1NTQ2MDMwMA==.2',
#       'filter_type': 0,
#       'like_and_view_counts_disabled': False,
#       'integrity_review_decision': 'pending',
#       'caption_is_edited': False,
#       'text_post_app_info': {'is_reply': False,
#        'reply_control': 'everyone',
#        'reply_facepile_users': [],
#        'can_reply': True,
#        'direct_reply_count': 2310,
#        'hush_info': None,
#        'is_first_post': False,
#        'is_parent_edited': False,
#        'is_post_unavailable': False,
#        'link_preview_attachment': None,
#        'quote_count': 787,
#        'reply_to_author': None,
#        'repost_count': 1371,
#        'self_thread_count': 0,
#        'share_info': {'can_quote_post': True,
#         'can_repost': True,
# ...
