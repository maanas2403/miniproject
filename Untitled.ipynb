# %%
import numpy as np
import pandas as pd
import datetime

# %%
from threads_interface import ThreadsInterface

# %%
ti=ThreadsInterface()

# %%
def func(id):
    data_df=pd.DataFrame()
    data=ti.retrieve_user_threads(id)
    data_threads=data['data']['mediaData']['threads']
    if len(data_threads) == 0:
        return "No threads"
    else:
        data_captions = []
        for item in data_threads:
            post = item['thread_items'][0]['post']
            caption_text = post['caption']['text'] if post['caption'] and post['caption']['text'] else "No caption"
            replies_text = item['thread_items'][0]['view_replies_cta_string'] or "No replies"
            replies_text = replies_text.replace(" replies", "").strip() if replies_text else "No replies"
            
            data_captions.append({
                'users': post['user']['username'],
                'user id': post['user']['pk'],
                'captions': caption_text,
                'Verified': post['user']['is_verified'],
                'Likes': post['like_count'],
                'Replies': replies_text,
                'Thread_id': post['pk'],
                'profilePicture': post['user']['profile_pic_url'],
                'takenAt': post['taken_at']
            })
        data_df=pd.DataFrame(data_captions)
        data_df['date']=data_df['takenAt'].apply(lambda x: datetime.datetime.fromtimestamp(x).day)
        data_df['month']=data_df['takenAt'].apply(lambda x: datetime.datetime.fromtimestamp(x).month)
        data_df['year']=data_df['takenAt'].apply(lambda x: datetime.datetime.fromtimestamp(x).year)
        data_df['hour']=data_df['takenAt'].apply(lambda x: datetime.datetime.fromtimestamp(x).hour)
        data_df['minute']=data_df['takenAt'].apply(lambda x: datetime.datetime.fromtimestamp(x).minute)
        return data_df

# %%
instagram_df=func(ti.retrieve_user_id('instagram'))
instagram_df
# Out:
#         users   user id                                           captions  \
# 0   instagram  25025320  favorite holiday drink that gives you all the ...
# 1   instagram  25025320  “The universe needs a different version of you...
# 2   instagram  25025320  hiii from the @meowparlour — part cat café, pa...
# 3   instagram  25025320       so how do we *really* feel about fruit cake?
# 4   instagram  25025320                           update: did it anyways 🤭
# 5   instagram  25025320                  does anyone actually like eggnog?
# 6   instagram  25025320                           best holiday movie? go 👇
# 7   instagram  25025320  the new @percyseries show is out ❤️‍🔥 \n \nso ...
# 8   instagram  25025320           sagittarius always going big, never home
# 9   instagram  25025320  Defying gravity one backflip at a time🤸 \n \n...
# 10  instagram  25025320  what’s the most sentimental gift you’ve ever r...
# ...

# %%
neymar_df=func(ti.retrieve_user_id('neymarjr'))
threads_df=pd.concat([instagram_df,neymar_df])
neymar_df
# Out:
#       users   user id                              captions  Verified  Likes  \
# 0  neymarjr  26669533                 Bom final de semana 🤪      True  26495
# 1  neymarjr  26669533               Boa semana pra todos 👏🏽      True  26815
# 2  neymarjr  26669533    Faltou pouco pra chegar em paris 😅      True  22087
# 3  neymarjr  26669533  https://instagram.com/p/CufURjULxYt/      True  19167
# 4  neymarjr  26669533                Partiu 🇫🇷 season 23/24      True  26173
#
#   Replies            Thread_id  \
# 0   1,956  3146973311526752413
# 1   1,791  3144049538695448808
# 2   1,289  3143458044623489068
# 3     893  3143326003060698050
# 4      73  3143199690958939860
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1689368474    15      7
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1689019933    11      7
# ...

# %%
selena_df=func(ti.retrieve_user_id('selenagomez'))
threads_df=pd.concat([threads_df,selena_df])
selena_df
# Out:
#          users    user id                                           captions  \
# 0  selenagomez  460563723  Y’all have been asking for new music for a whi...
# 1  selenagomez  460563723  I’m thankful for so much in my life & one of t...
# 2  selenagomez  460563723                                                 Hi
#
#    Verified   Likes Replies            Thread_id  \
# 0      True   79225   1,545  3171441350175316348
# 1      True   80534   2,523  3152715387918354613
# 2      True  381062  24,145  3141288006701615503
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1692285291    17      8
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1690052983    23      7
# 2  https://scontent.cdninstagram.com/v/t51.2885-1...  1688690733     7      7
#
#    year  hour  minute
# 0  2023    20      44
# 1  2023     0      39
# 2  2023     6      15

# %%
kylie_df=func(ti.retrieve_user_id('kyliejenner'))
kylie_df
# Out:
# 'No threads'

# %%
natgeo_df=func(ti.retrieve_user_id('natgeo'))
threads_df=pd.concat([threads_df,natgeo_df])
natgeo_df
# Out:
#      users user id                                           captions  \
# 0   natgeo  787132  Run out of ideas for what presents to give thi...
# 1   natgeo  787132  During the past year, 165 photographers in the...
# 2   natgeo  787132                                         No caption
# 3   natgeo  787132  Raise your hand if you’ll be seeking out auror...
# 4   natgeo  787132  Raccoons are cute, but feeding them is not 😬\n...
# 5   natgeo  787132  Which of these did you hear about most this year?
# 6   natgeo  787132  How often did you think about the Roman Empire...
# 7   natgeo  787132                                         No caption
# 8   natgeo  787132                                         No caption
# 9   natgeo  787132  When turkeys were reintroduced about 50 years ...
# 10  natgeo  787132                                         No caption
# 11  natgeo  787132                                         No caption
# ...

# %%
kim_df=func(ti.retrieve_user_id('kimkardashian'))
threads_df=pd.concat([threads_df,kim_df])
kim_df
# Out:
#            users   user id                                           captions  \
# 0  kimkardashian  18428658  These dresses are my favorite!! Check your IG ...
# 1  kimkardashian  18428658  I love all three of these collections!!! I got...
# 2  kimkardashian  18428658  I’m on set right now and have seen so many of ...
#
#    Verified  Likes Replies            Thread_id  \
# 0      True   1179     230  3248574552812796441
# 1      True   1153     145  3248574255587523273
# 2      True   2516     734  3248512931851049934
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1701480286     2     12
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1701480250     2     12
# 2  https://scontent.cdninstagram.com/v/t51.2885-1...  1701472940     2     12
#
#    year  hour  minute
# 0  2023     6      54
# 1  2023     6      54
# 2  2023     4      52

# %%
nike_df=func(ti.retrieve_user_id('nike'))
threads_df=pd.concat([threads_df,nike_df])
nike_df
# Out:
#    users   user id                                           captions  \
# 0   nike  13460080  You can fight through anything.\nEspecially sc...
# 1   nike  13460080  Win or lose—we work.\n*Especially* if we lose....
# 2   nike  13460080  The club closes. The gym doesn’t.\nWill you be...
# 3   nike  13460080  A setback doesn’t excuse you from putting in t...
# 4   nike  13460080  Her greatness on the pitch was only matched by...
# 5   nike  13460080  The best season. Of any footballer. Ever. \n\n...
# 6   nike  13460080  @kaepernick7 ’s new capsule collection is here...
# 7   nike  13460080                      Check that ✔️ Only Basketball
# 8   nike  13460080  Make that two for 2️⃣2️⃣.\n\nCongratulations @...
# 9   nike  13460080  Congrats to the @LVAces on back-to-back WNBA C...
# 10  nike  13460080  The LeBron XXIs have arrived.\n\nBuilt to take...
# 11  nike  13460080  Kelvin leaves the world behind. 🌎\n\nIn his th...
# ...

# %%
ucl_df=func(ti.retrieve_user_id('championsleague'))
threads_df=pd.concat([threads_df,ucl_df])
ucl_df
# Out:
#               users     user id  \
# 0   championsleague  1269788896
# 1   championsleague  1269788896
# 2   championsleague  1269788896
# 3   championsleague  1269788896
# 4   championsleague  1269788896
# 5   championsleague  1269788896
# 6   championsleague  1269788896
# 7   championsleague  1269788896
# 8   championsleague  1269788896
# 9   championsleague  1269788896
# 10  championsleague  1269788896
# 11  championsleague  1269788896
# 12  championsleague  1269788896
# 13  championsleague  1269788896
# 14  championsleague  1269788896
# 15  championsleague  1269788896
# 16  championsleague  1269788896
# 17  championsleague  1269788896
# 18  championsleague  1269788896
# 19  championsleague  1269788896
# 20  championsleague  1269788896
# 21  championsleague  1269788896
# 22  championsleague  1269788896
# 23  championsleague  1269788896
# 24  championsleague  1269788896
#
#                                              captions  Verified  Likes  \
# ...

# %%
mbr_df=func(ti.retrieve_user_id('mrbeast'))
threads_df=pd.concat([threads_df,mbr_df])
mbr_df
# Out:
#      users     user id                                           captions  \
# 0  mrbeast  2278169415  Now that you’ve had sometime on here, what’s y...
# 1  mrbeast  2278169415           The winner of the Tesla is @mklord_ !!!!
# 2  mrbeast  2278169415  I feel like I’m cheating on Twitter by using t...
# 3  mrbeast  2278169415              Like this if @zuck should make me CEO
#
#    Verified   Likes Replies            Thread_id  \
# 0      True   21485   4,968  3154166424768295408
# 1      True   58956   8,673  3142614695249493120
# 2      True  263480  19,311  3140892015431945819
# 3      True  218235   8,787  3140579479058783575
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1690225960    25      7
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1688848886     9      7
# 2  https://scontent.cdninstagram.com/v/t51.2885-1...  1688643527     6      7
# ...

# %%
jlo_df=func(ti.retrieve_user_id('jlo'))
threads_df=pd.concat([threads_df,jlo_df])
jlo_df
# Out:
#    users    user id                                           captions  \
# 0    jlo  305701719  Can’t Get Enough CHRISTMAS 🎄🎅 #CantGetEnough #...
# 1    jlo  305701719  I’m still in love with you boy…. \n#CantGetEno...
# 2    jlo  305701719                                                 ❤️
# 3    jlo  305701719  New This Is Me Now collectible matte finish po...
# 4    jlo  305701719                                         No caption
# 5    jlo  305701719  Can’t Get Enough of that Beso💋\nGet the full l...
# 6    jlo  305701719                                         No caption
# 7    jlo  305701719  @Delola Award Winning Cocktails are perfect fo...
# 8    jlo  305701719  Let’s Pre-Save #CantGetEnough together ➡️😂 htt...
# 9    jlo  305701719  I #CantGetEnough @jlobeauty jlobeauty.com #Thi...
# 10   jlo  305701719  Things I #CantGetEnough of…#ThisIsMeNow https:...
# 11   jlo  305701719  This Is Me…Now #ELLEWIH ELLEmagazine www.elle...
# ...

# %%
marvel_df=func(ti.retrieve_user_id('marvel'))
threads_df=pd.concat([threads_df,marvel_df])
marvel_df
# Out:
#      users    user id                                           captions  \
# 0   marvel  204633036                                He’s come so far. 🥲
# 1   marvel  204633036                                         No caption
# 2   marvel  204633036        One thing he can’t do all day — the dishes.
# 3   marvel  204633036                                         No caption
# 4   marvel  204633036                           Higher. Furrier. Faster.
# 5   marvel  204633036                         head empty. only flerkens.
# 6   marvel  204633036                             Glow up (literally) ⚡️
# 7   marvel  204633036  The new limited-edition line of @warbyparker e...
# 8   marvel  204633036  Beware the goblins, wolves, and witches that m...
# 9   marvel  204633036                                 Girls night in 😊💗🌸
# 10  marvel  204633036                                         No caption
# 11  marvel  204633036                               caught you looking 👀
# ...

# %%
four33_df=func(ti.retrieve_user_id('433'))
threads_df=pd.concat([threads_df,four33_df])
four33_df
# Out:
#    users    user id                                           captions  \
# 0    433  253625977  Coventry City's Kasey Palmer did the Jude Bell...
# 1    433  253625977         𝑨𝒓𝒓𝒊𝒗𝒆𝒅 in Barcelona 🤙🇧🇷\n\n📸 @fcbarcelona
# 2    433  253625977                        United’s future is bright 🌟
# 3    433  253625977                          Did this really happen? 🥵
# 4    433  253625977                       𝗙𝗜𝗥𝗦𝗧 𝗣𝗥𝗘𝗠𝗜𝗘𝗥 𝗟𝗘𝗔𝗚𝗨𝗘 𝗚𝗢𝗔𝗟 ⚽️
# 5    433  253625977  Al Nassr beat Al Ittihad in a 𝑺𝑬𝑽𝑬𝑵-𝑮𝑶𝑨𝑳 𝑻𝑯𝑹𝑰𝑳...
# 6    433  253625977             cristiano is now 𝐓𝐎𝐏 𝐒𝐂𝐎𝐑𝐄𝐑 of 2023 🔥
# 7    433  253625977                                𝟓𝟑 𝐆𝐎𝐀𝐋𝐒 𝐈𝐍 𝟐𝟎𝟐𝟑 ⚽️
# 8    433  253625977                             Over to you, Arsenal 🫡
# 9    433  253625977        Newcastle’s top 4️⃣ hopes take a huge hit 😬
# 10   433  253625977  Sir Alex Ferguson: "Give me Zidane and 10 piec...
# 11   433  253625977                 Caption this, wrong answers only 😜
# ...

# %%
shakira_df=func(ti.retrieve_user_id('shakira'))
threads_df=pd.concat([threads_df,shakira_df])
shakira_df
# Out:
#       users    user id                                           captions  \
# 0   shakira  217867189  Les deseo que se hagan realidad los deseos de ...
# 1   shakira  217867189  Graduamos 105 niños y niñas de primaria en la ...
# 2   shakira  217867189  Tenemos mucho para dar gracias cierto? \nHappy...
# 3   shakira  217867189                  When the weather matches my mood.
# 4   shakira  217867189  What a pleasure to be at @britishvogue with my...
# 5   shakira  217867189  Menos mal hay hamaca en este estudio y visitas...
# 6   shakira  217867189  Mastering the art of the hat https://SML.lnk.t...
# 7   shakira  217867189  Aquí celebrando los Billboards. Gracias por da...
# 8   shakira  217867189      Something about elevators and hotel hallways.
# 9   shakira  217867189  Thank you for all the love and support! 4 numb...
# 10  shakira  217867189  Who needs a fancy sportscar when you have this...
# 11  shakira  217867189  Esto es increíble Gracias por tanto!! \nLos am...
# ...

# %%
ws_df=func(ti.retrieve_user_id('willsmith'))
threads_df=pd.concat([threads_df,ws_df])
ws_df
# Out:
#        users     user id            captions  Verified  Likes Replies  \
# 0  willsmith  3132929984  OFFICIAL STATEMENT      True  19351      No
#
#              Thread_id                                     profilePicture  \
# 0  3215817157512705406  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# 0  1697575309    18     10  2023     2      11

# %%
nba_df=func(ti.retrieve_user_id('nba'))
threads_df=pd.concat([threads_df,nba_df])
nba_df
# Out:
#    users   user id                                           captions  \
# 0    nba  20824486  Your NBA XMAS winners! 🎁🎁🎁🎁🎁\n\nWhich game was...
# 1    nba  20824486  50 POINTS.\n15 DIMES.\n4 STEALS.\n3 BLOCKS.\n8...
# 2    nba  20824486  10,000 career points for Luka Doncic‼️\n\nThro...
# 3    nba  20824486                                                 🎄💚
# 4    nba  20824486  LeBron’s 18th NBA XMAS! 🎄 \n\nCeltics/Lakers l...
# 5    nba  20824486        Jamal Murray goes baseline for the spike ⚒️
# 6    nba  20824486  Jalen Brunson caps off his 38-point Christmas ...
# 7    nba  20824486              10th NBA Christmas 🔜 for Steph Curry!
# 8    nba  20824486  Start your Christmas with triple the impact ⭐️...
# 9    nba  20824486  🎄 Less than 24 hours away from Christmas Day h...
# 10   nba  20824486                       Malik Monk ATTACKS the rim 😱
# 11   nba  20824486                     2022 championship brothers! 💛🏆
# ...

# %%
khloe_df=func(ti.retrieve_user_id('khloekardashian'))
threads_df=pd.concat([threads_df,khloe_df])
khloe_df
# Out:
#               users    user id  \
# 0   khloekardashian  208560325
# 1   khloekardashian  208560325
# 2   khloekardashian  208560325
# 3   khloekardashian  208560325
# 4   khloekardashian  208560325
# 5   khloekardashian  208560325
# 6   khloekardashian  208560325
# 7   khloekardashian  208560325
# 8   khloekardashian  208560325
# 9   khloekardashian  208560325
# 10  khloekardashian  208560325
#
#                                              captions  Verified  Likes  \
# 0   💔 We will never forget you. To the 2997 people...      True   8483
# 1                                          No caption      True      0
# 2                               👇🏼 \n\n@krisjenner ♥️      True  17741
# 3                                                 🐈‍⬛      True  22938
# 4                    Happy birthday P, we love you! 🩷      True  24899
# 5                                          No caption      True  26777
# 6                             We are sleepover crew 🩷      True  51627
# ...

# %%
ch_df=func(ti.retrieve_user_id('chrishemsworth'))
threads_df=pd.concat([threads_df,ch_df])
ch_df
# Out:
#              users     user id  \
# 0   chrishemsworth  1822594644
# 1   chrishemsworth  1822594644
# 2   chrishemsworth  1822594644
# 3   chrishemsworth  1822594644
# 4   chrishemsworth  1822594644
# 5   chrishemsworth  1822594644
# 6   chrishemsworth  1822594644
# 7   chrishemsworth  1822594644
# 8   chrishemsworth  1822594644
# 9   chrishemsworth  1822594644
# 10  chrishemsworth  1822594644
# 11  chrishemsworth  1822594644
# 12  chrishemsworth  1822594644
# 13  chrishemsworth  1822594644
# 14  chrishemsworth  1822594644
# 15  chrishemsworth  1822594644
# 16  chrishemsworth  1822594644
# 17  chrishemsworth  1822594644
# 18  chrishemsworth  1822594644
# 19  chrishemsworth  1822594644
# 20  chrishemsworth  1822594644
# 21  chrishemsworth  1822594644
# 22  chrishemsworth  1822594644
# 23  chrishemsworth  1822594644
# 24  chrishemsworth  1822594644
#
#                                              captions  Verified  Likes  \
# ...

# %%
miley_df=func(ti.retrieve_user_id('mileycyrus'))
threads_df=pd.concat([threads_df,miley_df])
miley_df
# Out:
#          users    user id                                           captions  \
# 0   mileycyrus  325734299                         USED TO BE YOUNG. OUT NOW.
# 1   mileycyrus  325734299  Sometimes it feels like my life started when H...
# 2   mileycyrus  325734299  USED TO BE YOUNG. OUT NOW.\n\nmileycyrus.lnk.t...
# 3   mileycyrus  325734299  USED TO BE YOUNG. OUT NOW.\n\nThis song is abo...
# 4   mileycyrus  325734299  I know I used to be crazy. I know I used to be...
# 5   mileycyrus  325734299  ESV CONTINUED (BYS) - TONIGHT @ 10 PM ET \nUSE...
# 6   mileycyrus  325734299          It's true. Used To Be Young. August 25th.
# 7   mileycyrus  325734299  Used To Be Young. August 25th. These lyrics we...
# 8   mileycyrus  325734299  Used To Be Young. August 25th. \n\nENDLESS SUM...
# 9   mileycyrus  325734299                     Used To Be Young. August 25th.
# 10  mileycyrus  325734299                     Used To Be Young. August 25th.
# ...

# %%
rdj_df=func(ti.retrieve_user_id('robertdowneyjr'))
threads_df=pd.concat([threads_df,rdj_df])
rdj_df
# Out:
#             users     user id  \
# 0  robertdowneyjr  1518284433
# 1  robertdowneyjr  1518284433
# 2  robertdowneyjr  1518284433
# 3  robertdowneyjr  1518284433
# 4  robertdowneyjr  1518284433
# 5  robertdowneyjr  1518284433
# 6  robertdowneyjr  1518284433
#
#                                             captions  Verified  Likes Replies  \
# 0  Not spooky - cybersecurity awareness month (Oc...      True   3441      80
# 1  Kids heading back to school? Let’s up the onli...      True   3664      67
# 2                                COOL FOOD. 1.23.24.      True   4648      85
# 3  Things to do while not worrying about online c...      True   2320      57
# 4                      A summer meal at Casa Tucci..      True   3065     126
# 5                                         No caption      True      0     179
# 6  Threading onto the runway with Matt and Em.. @...      True   3135     149
#
#              Thread_id                                     profilePicture  \
# ...

# %%
ryan_df=func(ti.retrieve_user_id('vancityreynolds'))
threads_df=pd.concat([threads_df,ryan_df])
ryan_df
# Out:
#               users     user id  \
# 0   vancityreynolds  1942463581
# 1   vancityreynolds  1942463581
# 2   vancityreynolds  1942463581
# 3   vancityreynolds  1942463581
# 4   vancityreynolds  1942463581
# 5   vancityreynolds  1942463581
# 6   vancityreynolds  1942463581
# 7   vancityreynolds  1942463581
# 8   vancityreynolds  1942463581
# 9   vancityreynolds  1942463581
# 10  vancityreynolds  1942463581
# 11  vancityreynolds  1942463581
# 12  vancityreynolds  1942463581
# 13  vancityreynolds  1942463581
# 14  vancityreynolds  1942463581
# 15  vancityreynolds  1942463581
# 16  vancityreynolds  1942463581
# 17  vancityreynolds  1942463581
# 18  vancityreynolds  1942463581
# 19  vancityreynolds  1942463581
# 20  vancityreynolds  1942463581
# 21  vancityreynolds  1942463581
# 22  vancityreynolds  1942463581
# 23  vancityreynolds  1942463581
# 24  vancityreynolds  1942463581
#
#                                              captions  Verified  Likes  \
# ...

# %%
dinho_df=func(ti.retrieve_user_id('ronaldinho'))
threads_df=pd.concat([threads_df,dinho_df])
dinho_df
# Out:
#          users    user id                                           captions  \
# 0   ronaldinho  979177642  Muito orgulho e felicidade em ser reconhecido ...
# 1   ronaldinho  979177642  Complimenti @acmilan !!!\n124 anni di questa b...
# 2   ronaldinho  979177642  Lembranças de um ano mágico na minha vida... H...
# 3   ronaldinho  979177642  Obrigado pelo carinho galera de Miami!!! 🇺🇸🇺🇸\...
# 4   ronaldinho  979177642  Ballon d'Or 2005 🏆\nSem palavras para descreve...
# 5   ronaldinho  979177642  Dia inesquecível na minha carreira!!! \nEm 200...
# 6   ronaldinho  979177642      128 anos do mengão!!! Parabéns flamengo 🔴⚫🤙🏾
# 7   ronaldinho  979177642  Pausa pro café do Bruxo antes do feriado kkkkk...
# 8   ronaldinho  979177642  Lembranças Mundial Sub-17!! 🏆\nMe lembro até h...
# 9   ronaldinho  979177642                                         No caption
# 10  ronaldinho  979177642  Regalo del mio fratello Alessandro Nesta dove ...
# ...

# %%
katy_df=func(ti.retrieve_user_id('katyperry'))
katy_df
# Out:
# 'No threads'

# %%
kourtney_df=func(ti.retrieve_user_id('kourtneykardash'))
threads_df=pd.concat([threads_df,kourtney_df])
kourtney_df
# Out:
#               users    user id  \
# 0   kourtneykardash  145821237
# 1   kourtneykardash  145821237
# 2   kourtneykardash  145821237
# 3   kourtneykardash  145821237
# 4   kourtneykardash  145821237
# 5   kourtneykardash  145821237
# 6   kourtneykardash  145821237
# 7   kourtneykardash  145821237
# 8   kourtneykardash  145821237
# 9   kourtneykardash  145821237
# 10  kourtneykardash  145821237
# 11  kourtneykardash  145821237
# 12  kourtneykardash  145821237
# 13  kourtneykardash  145821237
# 14  kourtneykardash  145821237
#
#                                              captions  Verified  Likes  \
# 0                          100 days until Christmas 🎄      True   4287
# 1                                    one month 🍂🌻🎃🛵🍁🔥      True   6200
# 2                                          No caption      True      0
# 3                                          peek a boo      True   9732
# 4                                     boop-oop-a-doop      True  10057
# ...

# %%
wc_df=func(ti.retrieve_user_id('fifaworldcup'))
threads_df=pd.concat([threads_df,wc_df])
wc_df
# Out:
#            users     user id  \
# 0   fifaworldcup  1328701983
# 1   fifaworldcup  1328701983
# 2   fifaworldcup  1328701983
# 3   fifaworldcup  1328701983
# 4   fifaworldcup  1328701983
# 5   fifaworldcup  1328701983
# 6   fifaworldcup  1328701983
# 7   fifaworldcup  1328701983
# 8   fifaworldcup  1328701983
# 9   fifaworldcup  1328701983
# 10  fifaworldcup  1328701983
# 11  fifaworldcup  1328701983
# 12  fifaworldcup  1328701983
# 13  fifaworldcup  1328701983
# 14  fifaworldcup  1328701983
# 15  fifaworldcup  1328701983
# 16  fifaworldcup  1328701983
# 17  fifaworldcup  1328701983
# 18  fifaworldcup  1328701983
# 19  fifaworldcup  1328701983
# 20  fifaworldcup  1328701983
# 21  fifaworldcup  1328701983
# 22  fifaworldcup  1328701983
# 23  fifaworldcup  1328701983
# 24  fifaworldcup  1328701983
#
#                                              captions  Verified  Likes  \
# 0                                        Guess who 👀💫      True    823
# ...

# %%
gag_df=func(ti.retrieve_user_id('9gag'))
threads_df=pd.concat([threads_df,gag_df])
gag_df
# Out:
#    users    user id                                           captions  \
# 0   9gag  259220806  If you long press your belly button, a fart wi...
# 1   9gag  259220806  Cold weather:\npros - get to wear my cool wint...
# 2   9gag  259220806                which is the proper way????????????
# 3   9gag  259220806  When someone says "you're not really my type" ...
# 4   9gag  259220806                             gang man shoe bar sway
# 5   9gag  259220806  Mocha is just an excuse for adults to drink ch...
# 6   9gag  259220806  Corporate Christmas party and theres only one ...
# 7   9gag  259220806  Did you know you can make your Uber name anyth...
# 8   9gag  259220806  Knowing what you know now, would you still hav...
# 9   9gag  259220806                                                 70
# 10  9gag  259220806                                                 69
# 11  9gag  259220806                                              食咗飯未？
# ...

# %%
mancity_df=func(ti.retrieve_user_id('mancity'))
threads_df=pd.concat([threads_df,mancity_df])
mancity_df
# Out:
#       users  user id                                           captions  \
# 0   mancity  5880761                                       🍬 MATCHDAY 🍬
# 1   mancity  5880761                 Wishing you a magical Christmas 🎄🩵
# 2   mancity  5880761          Can you share that pic with us, Nathan? 🤩
# 3   mancity  5880761                      Leading us to the Big Five! 💪
# 4   mancity  5880761             We are the champions… of the world! 🎶🕺
# 5   mancity  5880761  Araña's trophy collection just keeps on growin...
# 6   mancity  5880761  Wrapping up the Big Five in time for Christmas...
# 7   mancity  5880761  The most Club World Cup wins for a manager! 🏆\...
# 8   mancity  5880761                     Campeón del mundo… again! 🕷️🇦🇷
# 9   mancity  5880761                 Make that number 5️⃣ for the year!
# 10  mancity  5880761  🏆 Premier League\n🏆 FA Cup\n🏆 Champions League...
# 11  mancity  5880761                                        2023: 🏆🏆🏆🏆🏆
# ...

# %%
netflix_df=func(ti.retrieve_user_id('netflix'))
threads_df=pd.concat([threads_df,netflix_df])
netflix_df
# Out:
#       users    user id                                           captions  \
# 0   netflix  207587378  It's a new age for the universe. Rebel Moon - ...
# 1   netflix  207587378  NEW AVATAR: THE LAST AIRBENDER PICS JUST DROPP...
# 2   netflix  207587378                                The Three Queens!!!
# 3   netflix  207587378                                         No caption
# 4   netflix  207587378                                         No caption
# 5   netflix  207587378                                         No caption
# 6   netflix  207587378       what's your favorite line from she's the man
# 7   netflix  207587378  squid game: the challenge finale is TOMORROW\n...
# 8   netflix  207587378  William and Kate -- and The Crown's final epis...
# 9   netflix  207587378  😱 Sweet Home 2\n🗓️ May December \n🍗 Chicken Ru...
# 10  netflix  207587378  Formula 1: Drive to Survive + Full Swing = The...
# 11  netflix  207587378  it's 11/11 so let's celebrate millie bobby bro...
# ...

# %%
lv_df=func(ti.retrieve_user_id('louisvuitton'))
threads_df=pd.concat([threads_df,lv_df])
lv_df
# Out:
#            users    user id  \
# 0   louisvuitton  187619120
# 1   louisvuitton  187619120
# 2   louisvuitton  187619120
# 3   louisvuitton  187619120
# 4   louisvuitton  187619120
# 5   louisvuitton  187619120
# 6   louisvuitton  187619120
# 7   louisvuitton  187619120
# 8   louisvuitton  187619120
# 9   louisvuitton  187619120
# 10  louisvuitton  187619120
# 11  louisvuitton  187619120
# 12  louisvuitton  187619120
# 13  louisvuitton  187619120
# 14  louisvuitton  187619120
# 15  louisvuitton  187619120
# 16  louisvuitton  187619120
# 17  louisvuitton  187619120
# 18  louisvuitton  187619120
# 19  louisvuitton  187619120
# 20  louisvuitton  187619120
# 21  louisvuitton  187619120
# 22  louisvuitton  187619120
# 23  louisvuitton  187619120
# 24  louisvuitton  187619120
#
#                                              captions  Verified  Likes  \
# 0   Enchant the winter celebrations with the Maiso...      True   1534
# ...

# %%
mcu_df=func(ti.retrieve_user_id('marvelstudios'))
mcu_df
# Out:
# 'No threads'

# %%
rachel_df=func(ti.retrieve_user_id('jenniferaniston'))
threads_df=pd.concat([threads_df,rachel_df])
rachel_df
# Out:
#              users      user id captions  Verified  Likes Replies  \
# 0  jenniferaniston  21388754496       👋🏼      True  54615   5,081
#
#              Thread_id                                     profilePicture  \
# 0  3141075732188360501  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# 0  1688665428     6      7  2023    23      13

# %%
manutd_df=func(ti.retrieve_user_id('manchesterunited'))
threads_df=pd.concat([threads_df,manutd_df])
manutd_df
# Out:
#                users    user id  \
# 0   manchesterunited  491527077
# 1   manchesterunited  491527077
# 2   manchesterunited  491527077
# 3   manchesterunited  491527077
# 4   manchesterunited  491527077
# 5   manchesterunited  491527077
# 6   manchesterunited  491527077
# 7   manchesterunited  491527077
# 8   manchesterunited  491527077
# 9   manchesterunited  491527077
# 10  manchesterunited  491527077
# 11  manchesterunited  491527077
# 12  manchesterunited  491527077
# 13  manchesterunited  491527077
# 14  manchesterunited  491527077
# 15  manchesterunited  491527077
# 16  manchesterunited  491527077
# 17  manchesterunited  491527077
# 18  manchesterunited  491527077
# 19  manchesterunited  491527077
# 20  manchesterunited  491527077
# 21  manchesterunited  491527077
# 22  manchesterunited  491527077
# 23  manchesterunited  491527077
# 24  manchesterunited  491527077
#
#                                              captions  Verified  Likes  \
# ...

# %%
anitta_df=func(ti.retrieve_user_id('anitta'))
threads_df=pd.concat([threads_df,anitta_df])
anitta_df
# Out:
#      users   user id                                           captions  \
# 0   anitta  26633036  Quem já ouviu #JogaPraLua hoje notou alguma no...
# 1   anitta  26633036  Gostaram de ouvir um trechinho de Joga pra Lua...
# 2   anitta  26633036  TACA PLAAAAY EM BELLAKEO\n\nhttps://open.spoti...
# 3   anitta  26633036  “BELLAKEO”🥷 @pesopluma feat Euzinha amanhã 7/1...
# 4   anitta  26633036                                     ✨ #VogueArabia
# 5   anitta  26633036                                   #LatinGrammy ✨💃🏽
# 6   anitta  26633036  Wow! Queria que la fiesta nunca terminara! 🇧🇷🔥...
# 7   anitta  26633036               Sevilla, estoy lista para ustedes 💃🏽
# 8   anitta  26633036  MONSTRÃO com o @dennisdj já está disponível e ...
# 9   anitta  26633036  tava aqui olhando minhas fantasias antigas de ...
# 10  anitta  26633036                         Aiiiii que delícia o verão
# 11  anitta  26633036  Mil Veces, canción y vídeo finalmente disponib...
# ...

# %%
pubity_df=func(ti.retrieve_user_id('pubity'))
threads_df=pd.concat([threads_df,pubity_df])
pubity_df
# Out:
#      users     user id                                           captions  \
# 0   pubity  1431724849  Wholesome moment 103-year-old man reunited wit...
# 1   pubity  1431724849                                          Goodnight
# 2   pubity  1431724849           Dog just wants to play catch with her 🥹🥹
# 3   pubity  1431724849                         She said ✨ I am the gift ✨
# 4   pubity  1431724849               Acts that brighten everyone’s day ❤️
# 5   pubity  1431724849  How was your Christmas? 🤳🏼📸 Let’s share our fa...
# 6   pubity  1431724849                               A star in the making
# 7   pubity  1431724849                     Clearly they’re siblings 🤭❤️🎅🏼
# 8   pubity  1431724849                        Poor dog was embarrassed 🥺😅
# 9   pubity  1431724849  Why have I seen 728293 posts today about long ...
# 10  pubity  1431724849                    Christmas activities in Florida
# 11  pubity  1431724849        It’s his world and we’re all living in it 🐱
# ...

# %%
zuck_df=func(ti.retrieve_user_id('zuck'))
threads_df=pd.concat([threads_df,zuck_df])
zuck_df
# Out:
#    users user id                                           captions  Verified  \
# 0   zuck  314216  Today we're opening Threads to more countries ...      True
# 1   zuck  314216  Starting a test where posts from Threads accou...      True
# 2   zuck  314216  Testing a way to categorize your posts with a ...      True
# 3   zuck  314216  We're bringing Llama 2 to @microsoft's Azure A...      True
# 4   zuck  314216           Who do you have winning tonight's fight?      True
# 5   zuck  314216                                         No caption      True
# 6   zuck  314216  Catching up on video games while recovering fr...      True
# 7   zuck  314216  How I feel about polls and GIFs rolling out to...      True
# 8   zuck  314216  Good conversation with @hubermanlab and @cilla...      True
# 9   zuck  314216   Rolling out Edit and Voice Threads today. Enjoy!      True
# 10  zuck  314216  First ever podcast with our photorealistic ava...      True
# ...

# %%
ellen_df=func(ti.retrieve_user_id('ellendegeneres'))
threads_df=pd.concat([threads_df,ellen_df])
ellen_df
# Out:
#              users   user id  \
# 0   ellendegeneres  18918467
# 1   ellendegeneres  18918467
# 2   ellendegeneres  18918467
# 3   ellendegeneres  18918467
# 4   ellendegeneres  18918467
# 5   ellendegeneres  18918467
# 6   ellendegeneres  18918467
# 7   ellendegeneres  18918467
# 8   ellendegeneres  18918467
# 9   ellendegeneres  18918467
# 10  ellendegeneres  18918467
# 11  ellendegeneres  18918467
# 12  ellendegeneres  18918467
# 13  ellendegeneres  18918467
# 14  ellendegeneres  18918467
# 15  ellendegeneres  18918467
# 16  ellendegeneres  18918467
# 17  ellendegeneres  18918467
# 18  ellendegeneres  18918467
# 19  ellendegeneres  18918467
# 20  ellendegeneres  18918467
# 21  ellendegeneres  18918467
# 22  ellendegeneres  18918467
# 23  ellendegeneres  18918467
# 24  ellendegeneres  18918467
#
#                                              captions  Verified  Likes  \
# 0   Apparently this is one of the most memorable m...      True   3131
# ...

# %%
netbrasil_df=func(ti.retrieve_user_id('netflixbrasil'))
threads_df=pd.concat([threads_df,netbrasil_df])
netbrasil_df
# Out:
#             users     user id  \
# 0   netflixbrasil  1479382961
# 1   netflixbrasil  1479382961
# 2   netflixbrasil  1479382961
# 3   netflixbrasil  1479382961
# 4   netflixbrasil  1479382961
# 5   netflixbrasil  1479382961
# 6   netflixbrasil  1479382961
# 7   netflixbrasil  1479382961
# 8   netflixbrasil  1479382961
# 9   netflixbrasil  1479382961
# 10  netflixbrasil  1479382961
# 11  netflixbrasil  1479382961
# 12  netflixbrasil  1479382961
# 13  netflixbrasil  1479382961
# 14  netflixbrasil  1479382961
# 15  netflixbrasil  1479382961
# 16  netflixbrasil  1479382961
# 17  netflixbrasil  1479382961
# 18  netflixbrasil  1479382961
# 19  netflixbrasil  1479382961
# 20  netflixbrasil  1479382961
# 21  netflixbrasil  1479382961
# 22  netflixbrasil  1479382961
# 23  netflixbrasil  1479382961
# 24  netflixbrasil  1479382961
#
#                                              captions  Verified  Likes  \
# 0   Sim, eu chorei com essa cena de A Fuga das Gal...      True   3259
# ...

# %%
obama_df=func(ti.retrieve_user_id('barackobama'))
threads_df=pd.concat([threads_df,obama_df])
obama_df
# Out:
#           users   user id                                           captions  \
# 0   barackobama  10206720  To all those lighting the Kinara today, Michel...
# 1   barackobama  10206720  This year has tested us in many ways, but Chri...
# 2   barackobama  10206720  As I usually do during this time of year, I wa...
# 3   barackobama  10206720                                         No caption
# 4   barackobama  10206720  We’re seeing record ACA enrollment by American...
# 5   barackobama  10206720  If you’re looking for a way to give back this ...
# 6   barackobama  10206720  Richard Hunt was an acclaimed sculptor and one...
# 7   barackobama  10206720  You heard, @POTUS — the Affordable Care is sti...
# 8   barackobama  10206720  Had fun surprising a group of students at Park...
# 9   barackobama  10206720  Hanukkah has always been a celebration of resi...
# 10  barackobama  10206720  Over the last two months, we’ve seen a rise in...
# ...

# %%
netbrasil_df=func(ti.retrieve_user_id('netflixbrasil'))
threads_df=pd.concat([threads_df,netbrasil_df])
netbrasil_df
# Out:
#             users     user id  \
# 0   netflixbrasil  1479382961
# 1   netflixbrasil  1479382961
# 2   netflixbrasil  1479382961
# 3   netflixbrasil  1479382961
# 4   netflixbrasil  1479382961
# 5   netflixbrasil  1479382961
# 6   netflixbrasil  1479382961
# 7   netflixbrasil  1479382961
# 8   netflixbrasil  1479382961
# 9   netflixbrasil  1479382961
# 10  netflixbrasil  1479382961
# 11  netflixbrasil  1479382961
# 12  netflixbrasil  1479382961
# 13  netflixbrasil  1479382961
# 14  netflixbrasil  1479382961
# 15  netflixbrasil  1479382961
# 16  netflixbrasil  1479382961
# 17  netflixbrasil  1479382961
# 18  netflixbrasil  1479382961
# 19  netflixbrasil  1479382961
# 20  netflixbrasil  1479382961
# 21  netflixbrasil  1479382961
# 22  netflixbrasil  1479382961
# 23  netflixbrasil  1479382961
# 24  netflixbrasil  1479382961
#
#                                              captions  Verified  Likes  \
# 0   Sim, eu chorei com essa cena de A Fuga das Gal...      True   3259
# ...

# %%
fabri_df=func(ti.retrieve_user_id('fabriziorom'))
threads_df=pd.concat([threads_df,fabri_df])
fabri_df
# Out:
#           users    user id                                           captions  \
# 0   fabriziorom  642852668  Not only Leonardo Bonucci. Juventus also told ...
# 1   fabriziorom  642852668  Leonardo Bonucci, no longer part of the projec...
# 2   fabriziorom  642852668  Official, confirmed. Romain Favre signed for A...
# 3   fabriziorom  642852668  Understand Aston Villa official bid for Moussa...
# 4   fabriziorom  642852668  Official, confirmed. Angeliño has joined Galat...
# 5   fabriziorom  642852668  EXCL: Saudi side Al Ettifaq approached Moussa ...
# 6   fabriziorom  642852668  Understand talks for André Onana are ongoing, ...
# 7   fabriziorom  642852668  Understand PSG are not planning to sell or off...
# 8   fabriziorom  642852668  Renan Lodi to Olympique Marseille, it’s done a...
# 9   fabriziorom  642852668  Understand AC Milan have left talks for Adama ...
# 10  fabriziorom  642852668  Liverpool are actively working to sign a new m...
# ...

# %%
galgadot_df=func(ti.retrieve_user_id('gal_gadot'))
threads_df=pd.concat([threads_df,galgadot_df])
galgadot_df
# Out:
#        users   user id                                           captions  \
# 0  gal_gadot  20788692  Soooooo excited for all of you to meet Rachel ...
# 1  gal_gadot  20788692  Bravo Margot Robbie and Greta Gerwig! You’ve c...
# 2  gal_gadot  20788692                           Did I make it in time? 😅
#
#    Verified  Likes Replies            Thread_id  \
# 0      True   4621     654  3146328838791150858
# 1      True  12535     445  3144289890626994427
# 2      True  10159     757  3141223683930799211
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1689291647    14      7
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1689048585    11      7
# 2  https://scontent.cdninstagram.com/v/t51.2885-1...  1688683065     7      7
#
#    year  hour  minute
# 0  2023     5      10
# 1  2023     9      39
# 2  2023     4       7

# %%
travis_df=func(ti.retrieve_user_id('travisscott'))
threads_df=pd.concat([threads_df,travis_df])
travis_df
# Out:
#          users   user id    captions  Verified  Likes Replies  \
# 0  travisscott  18900337  No caption      True  57594   3,280
#
#              Thread_id                                     profilePicture  \
# 0  3143861459275865221  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# 0  1688997512    10      7  2023    19      28

# %%
leo_df=func(ti.retrieve_user_id('leonardodicaprio'))
threads_df=pd.concat([threads_df,leo_df])
leo_df
# Out:
#               users     user id  \
# 0  leonardodicaprio  1506607755
# 1  leonardodicaprio  1506607755
#
#                                             captions  Verified  Likes Replies  \
# 0  Say Sí Al Yasuní. Yasuní Ntl. Park, 1 of Earth...      True   4064     158
# 1  Watch the official trailer for Killers of the ...      True   3826     334
#
#              Thread_id                                     profilePicture  \
# 0  3165693749820083198  https://scontent.cdninstagram.com/v/t51.2885-1...
# 1  3144624069752379586  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# 0  1691600222     9      8  2023    22      27
# 1  1689088422    11      7  2023    20      43

# %%
dybala_df=func(ti.retrieve_user_id('paulodybala'))
threads_df=pd.concat([threads_df,dybala_df])
dybala_df
# Out:
#           users    user id                                           captions  \
# 0   paulodybala  371299822                  Feliz navidad a todos amigos! ❤️🎄
# 1   paulodybala  371299822                    Grandissima vittoria ragazzi 💪🏽
# 2   paulodybala  371299822                                      Buen día!! ☀️
# 3   paulodybala  371299822                              Que estas pensando? 😂
# 4   paulodybala  371299822  https://www.instagram.com/reel/C1AahdHKbf6/?ig...
# 5   paulodybala  371299822                                             ⭐️⭐️⭐️
# 6   paulodybala  371299822  Hoy les voy a dejar algún recuerdos en esta nu...
# 7   paulodybala  371299822              Buen día amigos campeones del mundo 🏆
# 8   paulodybala  371299822                          Buona domenica ragazzi ☀️
# 9   paulodybala  371299822               Hola amigos de @threads soy Kaia 🐶 😂
# 10  paulodybala  371299822                             Te amo @orianasabatini
# ...

# %%
rose_df=func(ti.retrieve_user_id('roses_are_rosie'))
threads_df=pd.concat([threads_df,rose_df])
rose_df
# Out:
#              users     user id  \
# 0  roses_are_rosie  8004108750
# 1  roses_are_rosie  8004108750
# 2  roses_are_rosie  8004108750
#
#                                             captions  Verified   Likes  \
# 0        pics that couldn’t make the horizontal post      True  210237
# 1                                          행크 코 잘하죠~      True  166605
# 2  first post: things that made me happy this pas...      True  212287
#
#   Replies            Thread_id  \
# 0   5,494  3173075086265959412
# 1   4,767  3155341604246899416
# 2  15,941  3153802904589555326
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent-sea1-1.cdninstagram.com/v/t51...  1692480048    20      8
# 1  https://scontent-sea1-1.cdninstagram.com/v/t51...  1690366063    26      7
# 2  https://scontent-sea1-1.cdninstagram.com/v/t51...  1690182625    24      7
#
#    year  hour  minute
# 0  2023     2      50
# 1  2023    15      37
# 2  2023    12      40

# %%
depp_df=func(ti.retrieve_user_id('johnnydepp'))
threads_df=pd.concat([threads_df,depp_df])
depp_df
# Out:
#         users      user id                                           captions  \
# 0  johnnydepp  26432547111  To my dear ‘Modi’ film family, Köszönöm for al...
#
#    Verified  Likes Replies            Thread_id  \
# 0      True  18765     800  3232376520122103068
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1699549330     9     11
#
#    year  hour  minute
# 0  2023    22      32

# %%
disney_df=func(ti.retrieve_user_id('disney'))
threads_df=pd.concat([threads_df,disney_df])
disney_df
# Out:
#      users    user id                                           captions  \
# 0   disney  284634734  Disney has provided enchantment and wonder eve...
# 1   disney  284634734  Do you know the name of Walt Disney's hometown...
# 2   disney  284634734  No right, no wrong, no rules: We want to know ...
# 3   disney  284634734  Do you wanna prove how much you know about Fro...
# 4   disney  284634734  Is anyone else getting hungry? 😋🍽️ This quiz i...
# 5   disney  284634734  Fans like you have made our #Disney100 celebra...
# 6   disney  284634734  What if Star was… 👀\n\nSee Disney’s Wish, only...
# 7   disney  284634734  So many iconic Disney and Pixar films were rel...
# 8   disney  284634734  Cruella de Vil 101: Can you spot the correct a...
# 9   disney  284634734  Oh no big deal, just Walt Disney hanging out w...
# 10  disney  284634734  Today is the official 100th anniversary of The...
# 11  disney  284634734  Trivia Time: 30 Years of running amok, amok, a...
# ...

# %%
curry_df=func(ti.retrieve_user_id('stephencurry30'))
threads_df=pd.concat([threads_df,curry_df])
curry_df
# Out:
#              users    user id  \
# 0   stephencurry30  324599988
# 1   stephencurry30  324599988
# 2   stephencurry30  324599988
# 3   stephencurry30  324599988
# 4   stephencurry30  324599988
# 5   stephencurry30  324599988
# 6   stephencurry30  324599988
# 7   stephencurry30  324599988
# 8   stephencurry30  324599988
# 9   stephencurry30  324599988
# 10  stephencurry30  324599988
# 11  stephencurry30  324599988
# 12  stephencurry30  324599988
# 13  stephencurry30  324599988
#
#                                              captions  Verified  Likes  \
# 0   SPLASH!!!! The mission continues.…from 2020 wh...      True   3597
# 1   Honored to be partnering with @rakuten and the...      True    816
# 2                                   Almost that time…      True   9338
# 3   Our vote is our voice...so let’s  show up, vot...      True   3163
# 4   Keeping golf fun but trying to be like the pro...      True   2278
# 5   Thrilled to present Lucky Cruz and Roisin Scan...      True   2852
# ...

# %%
camila_df=func(ti.retrieve_user_id('camila_cabello'))
camila_df
# Out:
# 'No threads'

# %%
lovato_df=func(ti.retrieve_user_id('ddlovato'))
threads_df=pd.concat([threads_df,lovato_df])
lovato_df
# Out:
#        users    user id                                           captions  \
# 0   ddlovato  189393625  Are you signed up? Text me to find out more: (...
# 1   ddlovato  189393625  I have a song stuck in my head that I haven’t ...
# 2   ddlovato  189393625                     I told y’all aliens are real 😌
# 3   ddlovato  189393625                                                 😂😂
# 4   ddlovato  189393625                                     🥰🥰 Thank you!!
# 5   ddlovato  189393625  Breathing new life into the songs that played ...
# 6   ddlovato  189393625  Sorry Not Sorry - Rock Version  ft. slash is ...
# 7   ddlovato  189393625  Sorry Not Sorry Rock Version feat. Slash This...
# 8   ddlovato  189393625                                         No caption
# 9   ddlovato  189393625                                         No caption
# 10  ddlovato  189393625       Gimme your best thread puns.. I’ll go first…
# ...

# %%
virginia_df=func(ti.retrieve_user_id('virginia'))
threads_df=pd.concat([threads_df,virginia_df])
virginia_df
# Out:
#        users    user id                                           captions  \
# 0   virginia  266439562  UMA OTIMAAAAAAAA QUINTA P TODOSSSS!!!!!!! Que ...
# 1   virginia  266439562                                     BOM DIAAAAAAAA
# 2   virginia  266439562                                      Boa tardeeeee
# 3   virginia  266439562  Ja escutaram MARRENTO hoje?! \nhttps://open.sp...
# 4   virginia  266439562                     Eu n acostumei ainda c aqui 🤯🤯
# 5   virginia  266439562                     Eitaaa como ta sumida daquiiii
# 6   virginia  266439562                                     Boa noiteeeeee
# 7   virginia  266439562  https://open.spotify.com/track/5gH5JWzP4Iqqagm...
# 8   virginia  266439562                                 @zefelipecantor 💜💖
# 9   virginia  266439562  Feliz dia dos pais p todos os papais do mundoo...
# 10  virginia  266439562  Hj foi correria viu, preparei uma surpresa p J...
# ...

# %%
maluma_df=func(ti.retrieve_user_id('maluma'))
threads_df=pd.concat([threads_df,maluma_df])
maluma_df
# Out:
#     users   user id                                           captions  \
# 0  maluma  44059601  ES OFICIAL … “DON JUAN” 💿 afuera en la calle e...
# 1  maluma  44059601                                 GRACIAS MÁLAGA 🇪🇸💜
# 2  maluma  44059601  Nos vemos en Málaga hoy 🇪🇸🔥 \nComenten aquí 💜 ...
# 3  maluma  44059601  Aunque nos apaguen el #CELULAR 📱 vamos a insis...
#
#    Verified  Likes Replies            Thread_id  \
# 0      True   3482     130  3169306492260299348
# 1      True   7720     270  3142382044886296984
# 2      True   4795     327  3141687926388197298
# 3      True   5831     529  3141268284615454701
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1692030820    14      8
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1688821152     8      7
# 2  https://scontent.cdninstagram.com/v/t51.2885-1...  1688738407     7      7
# ...

# %%
mendes_df=func(ti.retrieve_user_id('shawnmendes'))
mendes_df
# Out:
# 'No threads'

# %%
sporcent_df=func(ti.retrieve_user_id('sportscenter'))
threads_df=pd.concat([threads_df,sporcent_df])
sporcent_df
# Out:
#            users    user id  \
# 0   sportscenter  505182045
# 1   sportscenter  505182045
# 2   sportscenter  505182045
# 3   sportscenter  505182045
# 4   sportscenter  505182045
# 5   sportscenter  505182045
# 6   sportscenter  505182045
# 7   sportscenter  505182045
# 8   sportscenter  505182045
# 9   sportscenter  505182045
# 10  sportscenter  505182045
# 11  sportscenter  505182045
# 12  sportscenter  505182045
# 13  sportscenter  505182045
# 14  sportscenter  505182045
# 15  sportscenter  505182045
# 16  sportscenter  505182045
# 17  sportscenter  505182045
# 18  sportscenter  505182045
# 19  sportscenter  505182045
# 20  sportscenter  505182045
# 21  sportscenter  505182045
# 22  sportscenter  505182045
# 23  sportscenter  505182045
# 24  sportscenter  505182045
#
#                                              captions  Verified  Likes  \
# 0                                          Thoughts 🤔      True   2478
# ...

# %%
bmw_df=func(ti.retrieve_user_id('bmw'))
threads_df=pd.concat([threads_df,bmw_df])
bmw_df
# Out:
#    users   user id                                           captions  \
# 0    bmw  43109246  When the drive is 𝘵𝘩𝘪𝘴 enchanting ❄️🌲\n📸: @dan...
# 1    bmw  43109246  Road trip to Route de Thorenc, the south of Fr...
# 2    bmw  43109246  This is the perfect time of year to indulge in...
# 3    bmw  43109246  Hallo, hola, bonjour, ciao 👋 \nWelcoming 🇪🇺 to...
# 4    bmw  43109246  There’s a feeling only a BMW can bring. Watch ...
# 5    bmw  43109246                                         No caption
# 6    bmw  43109246  Interior close-ups from concept to product ⚡😍\...
# 7    bmw  43109246  Ever. Green.\n\nThe BMW M135i xDrive with M Pe...
# 8    bmw  43109246  Too early? ☃️ 🥶\n\nThe BMW i4 M50:\nPower cons...
# 9    bmw  43109246  We all know it: Pumpkin Spice Season is over.\...
# 10   bmw  43109246  Road trip through Sanremo, Italy 📍🇮🇹 From city...
# 11   bmw  43109246  Road tripping on two and four wheels. Finding ...
# ...

# %%
lfc_df=func(ti.retrieve_user_id('liverpoolfc'))
threads_df=pd.concat([threads_df,lfc_df])
lfc_df
# Out:
#           users    user id                                           captions  \
# 0   liverpoolfc  187102427  The most assists for a defender in the #PL... ...
# 1   liverpoolfc  187102427                             Solid tonight, Ibou 👏🧱
# 2   liverpoolfc  187102427                                 It finishes level.
# 3   liverpoolfc  187102427                           All square at the break.
# 4   liverpoolfc  187102427                                                  👑
# 5   liverpoolfc  187102427  Into the top 🔟 scorers in #PL history 😮‍💨 \n\n...
# 6   liverpoolfc  187102427  SALAHHHH!!!\n\nA superb ball from Trent before...
# 7   liverpoolfc  187102427  Underway! Follow live here: https://bit.ly/3Zq...
# 8   liverpoolfc  187102427                                Warm-ups complete 💪
# 9   liverpoolfc  187102427                                 Anfield arrivals 👋
# 10  liverpoolfc  187102427               Here’s how we line up for #LIVARS 👊🔴
# ...

# %%
pc_df=func(ti.retrieve_user_id('priyankachopra'))
pc_df
# Out:
# 'No threads'

# %%
olivia_df=func(ti.retrieve_user_id('oliviarodrigo'))
threads_df=pd.concat([threads_df,olivia_df])
olivia_df
# Out:
#            users     user id  \
# 0  oliviarodrigo  1625608507
# 1  oliviarodrigo  1625608507
#
#                                             captions  Verified   Likes  \
# 0  new GUTS merch!!! https://oliviarodrigo.lnk.to...      True   45017
# 1  i have arrived on threads to remind u to liste...      True  101313
#
#   Replies            Thread_id  \
# 0     499  3147029480883507900
# 1   4,132  3140646231893602767
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1689375170    15      7
# 1  https://scontent.cdninstagram.com/v/t51.2885-1...  1688614227     6      7
#
#    year  hour  minute
# 0  2023     4      22
# 1  2023     9       0

# %%
zayn_df=func(ti.retrieve_user_id('zayn'))
threads_df=pd.concat([threads_df,zayn_df])
zayn_df
# Out:
#   users     user id                                           captions  \
# 0  zayn  2033147472               http://zayn.lnk.to/lovelikethisvideo
# 1  zayn  2033147472                                       Bradford! 🇬🇧
# 2  zayn  2033147472                         http://zayn.lnk.to/presave
# 3  zayn  2033147472  Love Like This. 21st of July\nhttp://zayn.lnk....
# 4  zayn  2033147472                                         No caption
# 5  zayn  2033147472  Love Like This. July 21st \nhttp://zayn.lnk.to...
#
#    Verified  Likes Replies            Thread_id  \
# 0      True  40695     709  3151219666889484331
# 1      True  37199     473  3150420125240534397
# 2      True  54516     632  3149607808311202694
# 3      True  44763     968  3146270202605309036
# 4      True      0     549  3145458886747541879
# 5      True  57019   1,809  3143897960332351871
#
#                                       profilePicture     takenAt  date  month  \
# ...

# %%
ufc_df=func(ti.retrieve_user_id('ufc'))
threads_df=pd.concat([threads_df,ufc_df])
ufc_df
# Out:
#    users   user id                                           captions  \
# 0    ufc  22832340  Time to pick your first #UFCHonors winner! 🏆\n...
# 1    ufc  22832340  Stacking up nicely 🔥\n\n@FunkMasterMMA will ma...
# 2    ufc  22832340  Dana just dropped some HUGE fight news before ...
# 3    ufc  22832340                                         No caption
# 4    ufc  22832340                                         No caption
# 5    ufc  22832340                                         No caption
# 6    ufc  22832340                                         No caption
# 7    ufc  22832340                                         No caption
# 8    ufc  22832340                                         No caption
# 9    ufc  22832340                                         No caption
# 10   ufc  22832340                                         No caption
# 11   ufc  22832340  Some HUGE news confirmed for UFC299 in Miami!!...
# ...

# %%
richarlison_df=func(ti.retrieve_user_id('richarlison'))
threads_df=pd.concat([threads_df,richarlison_df])
richarlison_df
# Out:
#           users     user id  \
# 0   richarlison  2078719005
# 1   richarlison  2078719005
# 2   richarlison  2078719005
# 3   richarlison  2078719005
# 4   richarlison  2078719005
# 5   richarlison  2078719005
# 6   richarlison  2078719005
# 7   richarlison  2078719005
# 8   richarlison  2078719005
# 9   richarlison  2078719005
# 10  richarlison  2078719005
# 11  richarlison  2078719005
# 12  richarlison  2078719005
# 13  richarlison  2078719005
# 14  richarlison  2078719005
# 15  richarlison  2078719005
# 16  richarlison  2078719005
# 17  richarlison  2078719005
# 18  richarlison  2078719005
# 19  richarlison  2078719005
# 20  richarlison  2078719005
#
#                                              captions  Verified  Likes  \
# 0                                                   🔥      True   4541
# 1                                                   🚀      True   1501
# 2                                                  🙌🏽      True  10076
# ...

# %%
burak_df=func(ti.retrieve_user_id('cznburak'))
threads_df=pd.concat([threads_df,burak_df])
burak_df
# Out:
#        users    user id                                           captions  \
# 0   cznburak  303947497  https://www.instagram.com/reel/CytAkDJIjs-/?ig...
# 1   cznburak  303947497  Üzüntün öfkeye dönüşene kadar kimse neler hiss...
# 2   cznburak  303947497                                    İyi geceler ❤️🤲
# 3   cznburak  303947497                                        MAŞALLAH❤️🤲
# 4   cznburak  303947497                            En Güzel Bağ Sevgidir❤️
# 5   cznburak  303947497                                Tanıyan var mı?😂❤️🙈
# 6   cznburak  303947497  Allah Rahmet Eylesin Özkan abim çok üzgünüm , ...
# 7   cznburak  303947497                      Bazı insanlar bazen insanlar.
# 8   cznburak  303947497  Türkiye’de Threadsta 1 Milyon Takipçiye Ulaşan...
# 9   cznburak  303947497                                En Sevdiğim Resim❤️
# 10  cznburak  303947497                            En Güzel Bağ Sevgidir❤️
# ...

# %%
balvin_df=func(ti.retrieve_user_id('jbalvin'))
threads_df=pd.concat([threads_df,balvin_df])
balvin_df
# Out:
#       users   user id                                           captions  \
# 0   jbalvin  10482862  Feliz Navidad Familia 🎄 que sea un día especia...
# 1   jbalvin  10482862  Gracias por el amor a AMIGOS\nhttps://jbalvin....
# 2   jbalvin  10482862  “La culpa no fue tuya pero mía tampoco “\nAmig...
# 3   jbalvin  10482862  Estoy muy agradecido por el apoyo y cariño que...
# 4   jbalvin  10482862  Ya está disponible AMIGOS ❤️‍🔥 una canción que...
# 5   jbalvin  10482862  Te dije que vendría nueva música y un buen ami...
# 6   jbalvin  10482862  Familia,  tickets al Que Bueno Volver a Verte ...
# 7   jbalvin  10482862  https://www.instagram.com/p/Czj1Z_Zv_Z3/?igshi...
# 8   jbalvin  10482862  GRACIAS latinamericanfashionawards por recono...
# 9   jbalvin  10482862  Este momento fue realmente un honor ⚡️ GRACIAS...
# 10  jbalvin  10482862                    Brasil até breve, eu amo vocês.
# 11  jbalvin  10482862      ¿Cuál es ese sueño que te encantaría cumplir?
# ...

# %%
wolverine_df=func(ti.retrieve_user_id('thehughjackman'))
threads_df=pd.concat([threads_df,wolverine_df])
wolverine_df
# Out:
#              users    user id  \
# 0   thehughjackman  489110643
# 1   thehughjackman  489110643
# 2   thehughjackman  489110643
# 3   thehughjackman  489110643
# 4   thehughjackman  489110643
# 5   thehughjackman  489110643
# 6   thehughjackman  489110643
# 7   thehughjackman  489110643
# 8   thehughjackman  489110643
# 9   thehughjackman  489110643
# 10  thehughjackman  489110643
# 11  thehughjackman  489110643
# 12  thehughjackman  489110643
# 13  thehughjackman  489110643
# 14  thehughjackman  489110643
# 15  thehughjackman  489110643
# 16  thehughjackman  489110643
# 17  thehughjackman  489110643
# 18  thehughjackman  489110643
# 19  thehughjackman  489110643
# 20  thehughjackman  489110643
# 21  thehughjackman  489110643
# 22  thehughjackman  489110643
# 23  thehughjackman  489110643
# 24  thehughjackman  489110643
#
#                                              captions  Verified  Likes  \
# 0                     7am Christmas morning! Magical!      True   6852
# ...

# %%
ps_df=func(ti.retrieve_user_id('playstation'))
threads_df=pd.concat([threads_df,ps_df])
ps_df
# Out:
#           users  user id                                           captions  \
# 0   playstation  9766379  PS5 Memories of 2023: Stumbling into Alan Wake...
# 1   playstation  9766379  Perception Check: Successful 🔎\n\nDouble check...
# 2   playstation  9766379  Which holiday treat truly nourishes your soul?...
# 3   playstation  9766379  PS5 Memories of 2023: That feeling when you pl...
# 4   playstation  9766379    After a year of going fast, you deserve to idle
# 5   playstation  9766379  Kick your criminal career up a notch with the ...
# 6   playstation  9766379  Few settings deliver holiday magic like the wi...
# 7   playstation  9766379  Peek behind the bloodied curtain of Resident E...
# 8   playstation  9766379  Next stop: Los Santos 🌴🏙 Grand Theft Auto V he...
# 9   playstation  9766379  Suicide Squad: Kill the Justice League serves ...
# 10  playstation  9766379  Step into Japan's turbulent Edo period when Ri...
# ...

# %%
werneck_df=func(ti.retrieve_user_id('tatawerneck'))
threads_df=pd.concat([threads_df,werneck_df])
werneck_df
# Out:
#          users   user id                       captions  Verified  Likes  \
# 0  tatawerneck  26029182  Gente é pra fazer o que aqui?      True   7233
#
#   Replies            Thread_id  \
# 0   1,422  3143027903273012090
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent-sea1-1.cdninstagram.com/v/t51...  1688898145     9      7
#
#    year  hour  minute
# 0  2023    15      52

# %%
spears_df=func(ti.retrieve_user_id('britneyspears'))
threads_df=pd.concat([threads_df,spears_df])
spears_df
# Out:
#             users   user id  \
# 0   britneyspears  12246775
# 1   britneyspears  12246775
# 2   britneyspears  12246775
# 3   britneyspears  12246775
# 4   britneyspears  12246775
# 5   britneyspears  12246775
# 6   britneyspears  12246775
# 7   britneyspears  12246775
# 8   britneyspears  12246775
# 9   britneyspears  12246775
# 10  britneyspears  12246775
# 11  britneyspears  12246775
# 12  britneyspears  12246775
# 13  britneyspears  12246775
# 14  britneyspears  12246775
#
#                                              captions  Verified  Likes  \
# 0   Who’s ready to grab a cozy blanket … a cup of ...      True   3760
# 1   Thank you all for your support of my book The ...      True   3268
# 2   Make your only wish (this year) come true with...      True    746
# 3   Thank you to all the fans who made The Woman I...      True   7679
# 4   I wasn’t good, I was GREAT! The Legendary Quot...      True   1339
# 5   It’s happening ✨🤓📖 !!! My book is the highest ...      True  12315
# ...

# %%
shaq_df=func(ti.retrieve_user_id('shaq'))
threads_df=pd.concat([threads_df,shaq_df])
shaq_df
# Out:
#    users    user id                                           captions  \
# 0   shaq  206034174  https://www.instagram.com/tv/CS0QRVYABbo/?igsh...
# 1   shaq  206034174  https://www.instagram.com/p/C1E9FnloKDk/?igsh=...
# 2   shaq  206034174  https://www.instagram.com/p/C1A0NMKLo69/?igshi...
# 3   shaq  206034174  https://www.instagram.com/reel/C0-YlK5v-T4/?ig...
# 4   shaq  206034174  https://www.instagram.com/reel/C07svz0vWJR/?ig...
# 5   shaq  206034174  https://www.instagram.com/reel/C02sEgGxVJ_/?ig...
# 6   shaq  206034174  https://www.instagram.com/reel/C0r6kI2Ay3Z/?ig...
# 7   shaq  206034174  https://instagram.com/stories/shaqironeall/323...
# 8   shaq  206034174  https://www.instagram.com/reel/Czb1B_bvVsk/?ig...
# 9   shaq  206034174  The older you get the more you realize how pre...
# 10  shaq  206034174                 I say HMF YES, and yes I’m yelling
# 11  shaq  206034174  You already know my question. 4-2 in favor of ...
# ...

# %%
luis_df=func(ti.retrieve_user_id('luisitocomunica'))
luis_df
# Out:
# 'No threads'

# %%
netflixlat_df=func(ti.retrieve_user_id('netflixlat'))
threads_df=pd.concat([threads_df,netflixlat_df])
netflixlat_df
# Out:
#          users     user id                                           captions  \
# 0   netflixlat  1479381866  No soy Santa, pero les traigo un regalito de N...
# 1   netflixlat  1479381866  Estos días no me busquen porque ya tengo plane...
# 2   netflixlat  1479381866  ¿Creen que 'El niñero' quiera cuidarme? Sí se ...
# 3   netflixlat  1479381866  Yo después de los 20 platos de recalentado que...
# 4   netflixlat  1479381866                            Papi, ya lo hablamos...
# 5   netflixlat  1479381866  Es que en ‘Cindy la regia’ dicen mucho “sacas”...
# 6   netflixlat  1479381866       Yo: Dice que solo es una amiga.\nTambién yo:
# 7   netflixlat  1479381866  Queremos mucho al bebé Grinch, ¿verdad? Denme ...
# 8   netflixlat  1479381866  ⚠️¡Alerta de spoiler! ⚠️ ️ No mires este avanc...
# 9   netflixlat  1479381866  El regalito debajo del árbol: imágenes de la n...
# 10  netflixlat  1479381866  Cada reflejo  cuenta una historia... Y la hist...
# ...

# %%
efron_df=func(ti.retrieve_user_id('zacefron'))
threads_df=pd.concat([threads_df,efron_df])
efron_df
# Out:
#       users   user id                       captions  Verified  Likes Replies  \
# 0  zacefron  29421778  Hi guys! I’m on time for once      True  44419   2,880
#
#              Thread_id                                     profilePicture  \
# 0  3140553914381670618  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# 0  1688603222     6      7  2023     5      57

# %%
yt_df=func(ti.retrieve_user_id('youtube'))
threads_df=pd.concat([threads_df,yt_df])
yt_df
# Out:
#       users  user id                                           captions  \
# 0   youtube  1337343              dark theme just feels right in winter
# 1   youtube  1337343   videos are like snowflakes. each one is unique!!
# 2   youtube  1337343  the first step to caring for others is caring ...
# 3   youtube  1337343                      my dream vacay spot is my bed
# 4   youtube  1337343  a good cozy video has the same calming effect ...
# 5   youtube  1337343                          favorite genre of Shorts?
# 6   youtube  1337343                         cozy bookstore vlogs 📚 >>>
# 7   youtube  1337343                  what are you watching before bed?
# 8   youtube  1337343               send funny video compilations please
# 9   youtube  1337343  if you had to guess, what video have you watch...
# 10  youtube  1337343  nothing like a nice winter sunset walk in the ...
# 11  youtube  1337343  update your brain’s software with a good night...
# ...

# %%
blake_df=func(ti.retrieve_user_id('blakelively'))
threads_df=pd.concat([threads_df,blake_df])
blake_df
# Out:
#          users     user id                                       captions  \
# 0  blakelively  1437529575  …I thought they literally meant “cage fight”.
#
#    Verified  Likes Replies            Thread_id  \
# 0      True   6202     302  3141531260697018932
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1688719731     7      7
#
#    year  hour  minute
# 0  2023    14      18

# %%
kun_df=func(ti.retrieve_user_id('kunaguero'))
threads_df=pd.concat([threads_df,kun_df])
kun_df
# Out:
#         users    user id                                           captions  \
# 0   kunaguero  302920492  Disfruten este momento histórico . 3 veces con...
# 1   kunaguero  302920492                                    Lionel Messi 🥳🥳
# 2   kunaguero  302920492  Event #89 - 50K Hight Roller - Pasamos al Dia ...
# 3   kunaguero  302920492                                Qué pasa chavales ?
# 4   kunaguero  302920492  EVENT #79 - $2,500 BUY-IN - NO LIMIT HOLDEM - ...
# 5   kunaguero  302920492  Se termino el torneo gente , linda experiencia...
# 6   kunaguero  302920492                                                UFC
# 7   kunaguero  302920492                         WSOP Main Event - Day 2 💪🏽
# 8   kunaguero  302920492         Eso se lleva el campeón mundial de póker 👀
# 9   kunaguero  302920492  Día 2 en el mundial de póker . Venimos bien ge...
# 10  kunaguero  302920492                          Se viene Día 2 al Poker 😎
# ...

# %%
volima_df=func(ti.retrieve_user_id('gusttavolima'))
threads_df=pd.concat([threads_df,volima_df])
volima_df
# Out:
#            users   user id                                           captions  \
# 0   gusttavolima  22079794                           Oi vida! Boa semana!🏛️❤️
# 1   gusttavolima  22079794  Ensaio no meu ‘Paraíso Particular’…Mais tarde ...
# 2   gusttavolima  22079794                                          Oi vida!👀
# 3   gusttavolima  22079794  Mais um projeto desenvolvido com muito carinho...
# 4   gusttavolima  22079794       Qual das 4 músicas já é a favorita de vocês?
# 5   gusttavolima  22079794  Tá liberado!🏛️🏝️\nAssista agora aos primeiros ...
# 6   gusttavolima  22079794  ÁUDIOS DISPONÍVEIS!🏛️🏝️\nAs primeiras 4 faixas...
# 7   gusttavolima  22079794     COMPENSA!👀🔥\nAmanhã • 21h \n#ParaísoParticular
# 8   gusttavolima  22079794  Pra matar um pouco a curiosidade de vocês, con...
# 9   gusttavolima  22079794  Pegaaaa o boi … 🏛🏖️🌴 #Inesquecivel #ParaisoPar...
# 10  gusttavolima  22079794   Que pancadaaaaaa ave Maria… @matheusekauan 🏛️🏝️🚀
# ...

# %%
nyt_df=func(ti.retrieve_user_id('nytimes'))
threads_df=pd.concat([threads_df,nyt_df])
nyt_df
# Out:
#       users     user id                                           captions  \
# 0   nytimes  1624593034  A nationwide movement is trying to stop the co...
# 1   nytimes  1624593034  “I have been silent and quiet and composed. An...
# 2   nytimes  1624593034  Stephen Sondheim was widely acclaimed as a gen...
# 3   nytimes  1624593034  Israelis across religious and political divide...
# 4   nytimes  1624593034  From @nytopinion \n\n“In 2023, it felt as thou...
# 5   nytimes  1624593034  Paula Murphy, who broke racecar driving record...
# 6   nytimes  1624593034  Israel's evacuation orders and fighting have f...
# 7   nytimes  1624593034  With drones and infrared cameras, these veteri...
# 8   nytimes  1624593034  Serious medical errors rose in hospitals after...
# 9   nytimes  1624593034  Is it bad to wash your hair every day? Is arth...
# 10  nytimes  1624593034  You may have forgotten — or wanted to forget —...
# ...

# %%
cfc_df=func(ti.retrieve_user_id('chelseafc'))
threads_df=pd.concat([threads_df,cfc_df])
cfc_df
# Out:
#         users    user id                                           captions  \
# 0   chelseafc  244309106               Festive football incoming in SW6! 🎄🔵
# 1   chelseafc  244309106  Happy Christmas to all Chelsea fans celebratin...
# 2   chelseafc  244309106                                Defeat at Molineux.
# 3   chelseafc  244309106                     Debuting our away kit today! 🔵
# 4   chelseafc  244309106                                Christmas Eve XI. 🎅
# 5   chelseafc  244309106                  'Twas the day before Christmas. 🌲
# 6   chelseafc  244309106  Proud to be giving something back to our wonde...
# 7   chelseafc  244309106  Enjoy all those little moments this Christmas,...
# 8   chelseafc  244309106                          Happy birthday, Chilly! 💙
# 9   chelseafc  244309106                             Take it away, Misha… 🎤
# 10  chelseafc  244309106  🎉🎊 Happy birthday to our legendary former defe...
# ...

# %%
tasty_df=func(ti.retrieve_user_id('buzzfeedtasty'))
threads_df=pd.concat([threads_df,tasty_df])
tasty_df
# Out:
#             users     user id  \
# 0   buzzfeedtasty  2125506698
# 1   buzzfeedtasty  2125506698
# 2   buzzfeedtasty  2125506698
# 3   buzzfeedtasty  2125506698
# 4   buzzfeedtasty  2125506698
# 5   buzzfeedtasty  2125506698
# 6   buzzfeedtasty  2125506698
# 7   buzzfeedtasty  2125506698
# 8   buzzfeedtasty  2125506698
# 9   buzzfeedtasty  2125506698
# 10  buzzfeedtasty  2125506698
# 11  buzzfeedtasty  2125506698
# 12  buzzfeedtasty  2125506698
# 13  buzzfeedtasty  2125506698
# 14  buzzfeedtasty  2125506698
# 15  buzzfeedtasty  2125506698
# 16  buzzfeedtasty  2125506698
# 17  buzzfeedtasty  2125506698
# 18  buzzfeedtasty  2125506698
#
#                                              captions  Verified  Likes  \
# 0   POV: you tell me that your New Year's resoluti...      True     72
# 1   in the mood for wedding gifts so i'm making th...      True     47
# 2   whenever i eat fries i want them to never end,...      True     35
# ...

# %%
juliette_df=func(ti.retrieve_user_id('juliette'))
threads_df=pd.concat([threads_df,juliette_df])
juliette_df
# Out:
#        users    user id                                           captions  \
# 0   juliette  345498691  Bom dia! Vamos fazer uma brincadeira? \nResuma...
# 1   juliette  345498691                                      Feliz Natal 💚
# 2   juliette  345498691                                         No caption
# 3   juliette  345498691  Somos cactos, temos espinhos, mas também flore...
# 4   juliette  345498691                               Pedacinhos de mim ❤️
# 5   juliette  345498691  O #SextouDoBem hoje traz uma iniciativa linda ...
# 6   juliette  345498691  Bom dia pra quem foi dormir e perdeu a Beyoncé...
# 7   juliette  345498691  Hoje eu voltei ao Ministério Público do TCE-PB...
# 8   juliette  345498691  Não é você que vai matar minha fome de desejo,...
# 9   juliette  345498691  Tem gente que é muito difícil de dirigir 😂\n\n...
# 10  juliette  345498691  Curtindo o que me põe pra cima\nGente que me s...
# ...

# %%
saltbae_df=func(ti.retrieve_user_id('nusr_et'))
threads_df=pd.concat([threads_df,saltbae_df])
saltbae_df
# Out:
#       users    user id                                           captions  \
# 0   nusr_et  350708102                                    No salt no life
# 1   nusr_et  350708102                                          Operation
# 2   nusr_et  350708102                                        Wowww steak
# 3   nusr_et  350708102                                No risky no whiskey
# 4   nusr_et  350708102                                             Iconic
# 5   nusr_et  350708102                                         Gold night
# 6   nusr_et  350708102                                   Quality quantity
# 7   nusr_et  350708102                              Please Say masallah 🧿
# 8   nusr_et  350708102                                                Art
# 9   nusr_et  350708102  Thank you so much meta I love you for bringing...
# 10  nusr_et  350708102                                    No salt No life
# 11  nusr_et  350708102                                         He is here
#
# ...

# %%
bzrp_df=func(ti.retrieve_user_id('bizarrap'))
threads_df=pd.concat([threads_df,bzrp_df])
bzrp_df
# Out:
#       users     user id                     captions  Verified  Likes Replies  \
# 0  bizarrap  4469252771  endiamantado, siempre volao      True  66037   3,116
#
#              Thread_id                                     profilePicture  \
# 0  3140550162023483090  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# 0  1688602775     6      7  2023     5      49

# %%
luva_df=func(ti.retrieve_user_id('luvadepedreiro'))
threads_df=pd.concat([threads_df,luva_df])
luva_df
# Out:
#              users      user id  \
# 0   luvadepedreiro  47884249314
# 1   luvadepedreiro  47884249314
# 2   luvadepedreiro  47884249314
# 3   luvadepedreiro  47884249314
# 4   luvadepedreiro  47884249314
# 5   luvadepedreiro  47884249314
# 6   luvadepedreiro  47884249314
# 7   luvadepedreiro  47884249314
# 8   luvadepedreiro  47884249314
# 9   luvadepedreiro  47884249314
# 10  luvadepedreiro  47884249314
# 11  luvadepedreiro  47884249314
# 12  luvadepedreiro  47884249314
# 13  luvadepedreiro  47884249314
# 14  luvadepedreiro  47884249314
# 15  luvadepedreiro  47884249314
# 16  luvadepedreiro  47884249314
# 17  luvadepedreiro  47884249314
# 18  luvadepedreiro  47884249314
# 19  luvadepedreiro  47884249314
# 20  luvadepedreiro  47884249314
# 21  luvadepedreiro  47884249314
# 22  luvadepedreiro  47884249314
# 23  luvadepedreiro  47884249314
# 24  luvadepedreiro  47884249314
#
#                                              captions  Verified  Likes  \
# ...

# %%
jtb_df=func(ti.retrieve_user_id('justintimberlake'))
threads_df=pd.concat([threads_df,jtb_df])
jtb_df
# Out:
#               users    user id  \
# 0  justintimberlake  303054725
# 1  justintimberlake  303054725
# 2  justintimberlake  303054725
# 3  justintimberlake  303054725
# 4  justintimberlake  303054725
# 5  justintimberlake  303054725
# 6  justintimberlake  303054725
# 7  justintimberlake  303054725
#
#                                             captions  Verified  Likes Replies  \
# 0   Our first song together in 23 years is out now 💌      True   5012     176
# 1                                    BETTER PLACE 🫶🏻      True   2577     116
# 2   🔥🧯@firstwefeast \n\nhttps://youtu.be/97SPDxM3Ezw      True   1843      54
# 3                                             PTSD 🥵      True   2042      66
# 4                                         No caption      True      0       9
# 5                                                  👀      True   5495     209
# 6              ICU https://cocojones.lnk.to/ICURemix      True   1518     159
# ...

# %%
hoh_df=func(ti.retrieve_user_id('houseofhighlights'))
threads_df=pd.concat([threads_df,hoh_df])
hoh_df
# Out:
#                 users     user id  \
# 0   houseofhighlights  1254997058
# 1   houseofhighlights  1254997058
# 2   houseofhighlights  1254997058
# 3   houseofhighlights  1254997058
# 4   houseofhighlights  1254997058
# 5   houseofhighlights  1254997058
# 6   houseofhighlights  1254997058
# 7   houseofhighlights  1254997058
# 8   houseofhighlights  1254997058
# 9   houseofhighlights  1254997058
# 10  houseofhighlights  1254997058
# 11  houseofhighlights  1254997058
# 12  houseofhighlights  1254997058
# 13  houseofhighlights  1254997058
# 14  houseofhighlights  1254997058
# 15  houseofhighlights  1254997058
# 16  houseofhighlights  1254997058
# 17  houseofhighlights  1254997058
# 18  houseofhighlights  1254997058
# 19  houseofhighlights  1254997058
# 20  houseofhighlights  1254997058
# 21  houseofhighlights  1254997058
# 22  houseofhighlights  1254997058
# 23  houseofhighlights  1254997058
# 24  houseofhighlights  1254997058
#
# ...

# %%
srk_df=func(ti.retrieve_user_id('iamsrk'))
threads_df=pd.concat([threads_df,srk_df])
srk_df
# Out:
#      users    user id                                           captions  \
# 0   iamsrk  628480450  ఒక జవాన్ మరియు జస్టిస్.\nమహిళలు మరియు వాళ్ళ ప్...
# 1   iamsrk  628480450  நீதி மற்றும் ஒரு ஜவான்\nபெண்கள் மற்றும் அவர்கள...
# 2   iamsrk  628480450  Of Justice & A Jawan. \nOf Women & their Venge...
# 3   iamsrk  628480450  ప్రేమ కొలవలేనిది , హద్దులు లేనిది అయ్యుండాలి ....
# 4   iamsrk  628480450  காதல் அளவிட முடியாததாகவும், கவலையற்றதாகவும், எ...
# 5   iamsrk  628480450  Ishq ho behisaab sa, beparwah, behadh sa! Kuch...
# 6   iamsrk  628480450  The Daring. The Dazzling. The Dangerous.\n\n#J...
# 7   iamsrk  628480450  Main achha hoon ya bura hoon… 30 days to find ...
# 8   iamsrk  628480450  పదండి, చిందేసే సమయం వచ్చింది! 😎\n#DhummeDhulip...
# 9   iamsrk  628480450  வாங்க, ஆட்டம் போட நேரம் வந்தாச்சு! 😎\n#VandhaE...
# 10  iamsrk  628480450  Presenting… #ZindaBanda! \n\nhttps://bit.ly/Zi...
# 11  iamsrk  628480450  The Sound of Jawan !\n\nSong out today at 12:5...
# ...

# %%
lewis_df=func(ti.retrieve_user_id('lewishamilton'))
threads_df=pd.concat([threads_df,lewis_df])
lewis_df
# Out:
#            users    user id           captions  Verified  Likes Replies  \
# 0  lewishamilton  197503026                 🫶🏾      True  23676     326
# 1  lewishamilton  197503026  🇹🇷 — back to work      True  17675     236
# 2  lewishamilton  197503026                📍🇭🇺      True  10393     258
# 3  lewishamilton  197503026                  😂      True  24847     317
# 4  lewishamilton  197503026      @mission44 🇬🇧      True  32885     797
#
#              Thread_id                                     profilePicture  \
# 0  3242509297454625828  https://scontent.cdninstagram.com/v/t51.2885-1...
# 1  3174362181432761664  https://scontent.cdninstagram.com/v/t51.2885-1...
# 2  3150390580931639028  https://scontent.cdninstagram.com/v/t51.2885-1...
# 3  3144052784390441193  https://scontent.cdninstagram.com/v/t51.2885-1...
# 4  3141577486081170663  https://scontent.cdninstagram.com/v/t51.2885-1...
#
#       takenAt  date  month  year  hour  minute
# ...

# %%
cnn_df=func(ti.retrieve_user_id('cnn'))
threads_df=pd.concat([threads_df,cnn_df])
cnn_df
# Out:
#    users    user id                                           captions  \
# 0    cnn  217723373                                         No caption
# 1    cnn  217723373  Here are 5️⃣ things you need to know today👇 \n...
# 2    cnn  217723373  Although ballet has diversified and changed ov...
# 3    cnn  217723373  Something shiny near a creek and a case of cur...
# 4    cnn  217723373  Human remains were found Sunday in connection ...
# 5    cnn  217723373  The Hubble Space Telescope captured a newly re...
# 6    cnn  217723373  Drone footage shows widespread destruction aft...
# 7    cnn  217723373  CNN's Gabe Cohen speaks with Black students ab...
# 8    cnn  217723373  Kanye West, who has made repeated antisemitic ...
# 9    cnn  217723373  Cognitive decline can begin years before signs...
# 10   cnn  217723373  A blizzard-fueling winter storm is sweeping ac...
# 11   cnn  217723373  Apple had already taken the offending Watch mo...
# ...

# %%
dp_df=func(ti.retrieve_user_id('dannapaola'))
threads_df=pd.concat([threads_df,dp_df])
dp_df
# Out:
#          users  user id                                           captions  \
# 0   dannapaola  7584726  “Deja que el fuego se lleve todo y mira tu dol...
# 1   dannapaola  7584726  Es que muchos están convencidos de que no hay ...
# 2   dannapaola  7584726  Aún te quiero 🥀 OUT NOW!! ♥️ Les entregamos es...
# 3   dannapaola  7584726  "Aún Te Quiero" mañana 🥀🖤⭐\n\n6pm mx \n\nhttps...
# 4   dannapaola  7584726  Te di todo y tú por nada lo vendiste 🥀🖤⭐\n\n"A...
# 5   dannapaola  7584726                                         No caption
# 6   dannapaola  7584726  Nadie pidió mi opinión, pero qué pedo con toda...
# 7   dannapaola  7584726  Ya se me había olvidado, hola bebes de threads...
# 8   dannapaola  7584726                                   Y esto que o que
# 9   dannapaola  7584726  Una noche decidiste que ya no me querías y al ...
# 10  dannapaola  7584726               Estoy llorando escuchando mi álbum 😭
# ...

# %%
arnold_df=func(ti.retrieve_user_id('schwarzenegger'))
threads_df=pd.concat([threads_df,arnold_df])
arnold_df
# Out:
#              users    user id  \
# 0   schwarzenegger  198945880
# 1   schwarzenegger  198945880
# 2   schwarzenegger  198945880
# 3   schwarzenegger  198945880
# 4   schwarzenegger  198945880
# 5   schwarzenegger  198945880
# 6   schwarzenegger  198945880
# 7   schwarzenegger  198945880
# 8   schwarzenegger  198945880
# 9   schwarzenegger  198945880
# 10  schwarzenegger  198945880
# 11  schwarzenegger  198945880
# 12  schwarzenegger  198945880
# 13  schwarzenegger  198945880
# 14  schwarzenegger  198945880
# 15  schwarzenegger  198945880
# 16  schwarzenegger  198945880
# 17  schwarzenegger  198945880
# 18  schwarzenegger  198945880
# 19  schwarzenegger  198945880
# 20  schwarzenegger  198945880
# 21  schwarzenegger  198945880
# 22  schwarzenegger  198945880
# 23  schwarzenegger  198945880
# 24  schwarzenegger  198945880
#
#                                              captions  Verified  Likes  \
# 0   I am listening to all of you and sharing more ...      True   6977
# ...

# %%
creators_df=func(ti.retrieve_user_id('creators'))
threads_df=pd.concat([threads_df,creators_df])
creators_df
# Out:
#        users     user id                                           captions  \
# 0   creators  8663171404                       “To Me, You Are Perfect” 👏❤️
# 1   creators  8663171404  BRB entering relaxation mode and setting email...
# 2   creators  8663171404  Whether you’re a seasoned pro or just starting...
# 3   creators  8663171404  What's your favorite way to spread a little IG...
# 4   creators  8663171404  It’s time for Office Hours with @emmyloop! \n\...
# 5   creators  8663171404  A little inspo for your next IG story, courtes...
# 6   creators  8663171404  Had the best time with our creator friends at ...
# 7   creators  8663171404  Threads is rolling out in Europe, starting TOD...
# 8   creators  8663171404  Instagram Live Producer is now available to al...
# 9   creators  8663171404  Looking for more Instagram tips & tricks? 🤳 Ch...
# 10  creators  8663171404  Ask us anything about being a creator on Threa...
# ...

# %%
tsr_df=func(ti.retrieve_user_id('theshaderoom'))
threads_df=pd.concat([threads_df,tsr_df])
tsr_df
# Out:
#            users     user id  \
# 0   theshaderoom  1497414823
# 1   theshaderoom  1497414823
# 2   theshaderoom  1497414823
# 3   theshaderoom  1497414823
# 4   theshaderoom  1497414823
# 5   theshaderoom  1497414823
# 6   theshaderoom  1497414823
# 7   theshaderoom  1497414823
# 8   theshaderoom  1497414823
# 9   theshaderoom  1497414823
# 10  theshaderoom  1497414823
# 11  theshaderoom  1497414823
# 12  theshaderoom  1497414823
# 13  theshaderoom  1497414823
# 14  theshaderoom  1497414823
# 15  theshaderoom  1497414823
# 16  theshaderoom  1497414823
# 17  theshaderoom  1497414823
# 18  theshaderoom  1497414823
# 19  theshaderoom  1497414823
# 20  theshaderoom  1497414823
# 21  theshaderoom  1497414823
# 22  theshaderoom  1497414823
# 23  theshaderoom  1497414823
# 24  theshaderoom  1497414823
#
#                                              captions  Verified  Likes  \
# 0           Loyal said he’s not playing with y’all 😭🥊      True    354
# ...

# %%
espn_df=func(ti.retrieve_user_id('espn'))
threads_df=pd.concat([threads_df,espn_df])
espn_df
# Out:
#    users  user id                                           captions  \
# 0   espn  1320207  Sydney McLaughlin-Levrone spoke about the impa...
# 1   espn  1320207             Welcome to the Suite Life of the NBA 🏀
# 2   espn  1320207  "Whether I play basketball for two or three mo...
# 3   espn  1320207  “As a Black woman, it’s about having confidenc...
# 4   espn  1320207  Julie Foudy sharing a special moment with the ...
# 5   espn  1320207  Carlos Alcaraz and Frances Tiafoe sporting the...
# 6   espn  1320207  Vanessa Bryant and the Lakers announced that a...
# 7   espn  1320207                          8.24 forever 💜💛 #MambaDay
# 8   espn  1320207  Novak Djokovic outlasted Carlos Alcaraz in a t...
# 9   espn  1320207                             Ant is taking over 🇺🇸😤
# 10  espn  1320207  Gunnar Henderson needed a single for a cycle b...
# 11  espn  1320207        Sha'Carri Richardson isn't messing around 👏
# 12  espn  1320207  Bryce Harper with the Phillie Phanatic bat for...
# ...

# %%
danbil_df=func(ti.retrieve_user_id('danbilzerian'))
threads_df=pd.concat([threads_df,danbil_df])
danbil_df
# Out:
#           users   user id                         captions  Verified  Likes  \
# 0  danbilzerian  50417061  @ignite is available in Sweeden      True   3828
#
#   Replies            Thread_id  \
# 0     244  3143015392134876026
#
#                                       profilePicture     takenAt  date  month  \
# 0  https://scontent.cdninstagram.com/v/t51.2885-1...  1688896653     9      7
#
#    year  hour  minute
# 0  2023    15      27

# %%
vs_df=func(ti.retrieve_user_id('victoriassecret'))
threads_df=pd.concat([threads_df,vs_df])
vs_df
# Out:
#               users  user id  \
# 0   victoriassecret  3416684
# 1   victoriassecret  3416684
# 2   victoriassecret  3416684
# 3   victoriassecret  3416684
# 4   victoriassecret  3416684
# 5   victoriassecret  3416684
# 6   victoriassecret  3416684
# 7   victoriassecret  3416684
# 8   victoriassecret  3416684
# 9   victoriassecret  3416684
# 10  victoriassecret  3416684
# 11  victoriassecret  3416684
# 12  victoriassecret  3416684
# 13  victoriassecret  3416684
# 14  victoriassecret  3416684
# 15  victoriassecret  3416684
# 16  victoriassecret  3416684
# 17  victoriassecret  3416684
# 18  victoriassecret  3416684
# 19  victoriassecret  3416684
# 20  victoriassecret  3416684
# 21  victoriassecret  3416684
# 22  victoriassecret  3416684
# 23  victoriassecret  3416684
# 24  victoriassecret  3416684
#
#                                              captions  Verified  Likes  \
# 0   Join host @amandadecadenet for an intimate dis...      True    128
# ...

# %%
coldplay_df=func(ti.retrieve_user_id('coldplay'))
threads_df=pd.concat([threads_df,coldplay_df])
coldplay_df
# Out:
#        users    user id                                           captions  \
# 0   coldplay  250131908                                         No caption
# 1   coldplay  250131908  Due to overwhelming demand, a fourth and final...
# 2   coldplay  250131908  Show #122, Kuala Lumpur \n\n#MusicOfTheSpheres...
# 3   coldplay  250131908  Terima kasih, Kuala Lumpur - that was EPIC 💗 ⚡...
# 4   coldplay  250131908                    Ready for the Kuala Lumpur show
# 5   coldplay  250131908  Thank you Perth. You truly made us feel on top...
# 6   coldplay  250131908                    Ready for the second Perth show
# 7   coldplay  250131908    Show #120, Perth\n\n#MusicOfTheSpheresWorldTour
# 8   coldplay  250131908   Thank you Perth - that was off the charts ⚡️💚💛⚡️
# 9   coldplay  250131908  Show #119, Jakarta\n\n📷 @annaleemedia \n\n#Col...
# 10  coldplay  250131908  Thank you for one of the best nights ever, Jak...
# ...

# %%
porsche_df=func(ti.retrieve_user_id('porsche'))
threads_df=pd.concat([threads_df,porsche_df])
porsche_df
# Out:
#      users    user id                                           captions  \
# 0  porsche  462752227              Pulling up today like…\n🎄@henrikdalee
# 1  porsche  462752227                         When they pocket dial you.
# 2  porsche  462752227                     What’s in your frunk? Show us👇
# 3  porsche  462752227  Us on our way back to Threads. \n🎥: @Lorenzo.k...
# 4  porsche  462752227  Our team pulling the strings for an unforgetta...
# 5  porsche  462752227  Together, we are a community ❤️ \nJoin us here...
# 6  porsche  462752227                         We see you. 👋 @startfinish
# 7  porsche  462752227          Diving into Threads like… 👋💛\n📸 @kefan404
#
#    Verified  Likes Replies            Thread_id  \
# 0      True  15743      63  3265492672092223704
# 1      True  23703     520  3264304713515128972
# 2      True   8299      97  3261399465750410891
# 3      True  11341     117  3258515993654451179
# 4      True   1590      60  3146149039497774010
# ...

# %%
jair_df=func(ti.retrieve_user_id('jairmessiasbolsonaro'))
threads_df=pd.concat([threads_df,jair_df])
jair_df
# Out:
#                    users    user id  \
# 0   jairmessiasbolsonaro  324756395
# 1   jairmessiasbolsonaro  324756395
# 2   jairmessiasbolsonaro  324756395
# 3   jairmessiasbolsonaro  324756395
# 4   jairmessiasbolsonaro  324756395
# 5   jairmessiasbolsonaro  324756395
# 6   jairmessiasbolsonaro  324756395
# 7   jairmessiasbolsonaro  324756395
# 8   jairmessiasbolsonaro  324756395
# 9   jairmessiasbolsonaro  324756395
# 10  jairmessiasbolsonaro  324756395
# 11  jairmessiasbolsonaro  324756395
# 12  jairmessiasbolsonaro  324756395
# 13  jairmessiasbolsonaro  324756395
# 14  jairmessiasbolsonaro  324756395
# 15  jairmessiasbolsonaro  324756395
# 16  jairmessiasbolsonaro  324756395
# 17  jairmessiasbolsonaro  324756395
# 18  jairmessiasbolsonaro  324756395
# 19  jairmessiasbolsonaro  324756395
# 20  jairmessiasbolsonaro  324756395
# 21  jairmessiasbolsonaro  324756395
# 22  jairmessiasbolsonaro  324756395
# 23  jairmessiasbolsonaro  324756395
# 24  jairmessiasbolsonaro  324756395
#
# ...

# %%
beckyg_df=func(ti.retrieve_user_id('iambeckyg'))
threads_df=pd.concat([threads_df,beckyg_df])
beckyg_df
# Out:
#         users   user id                                           captions  \
# 0   iambeckyg  16754881                                         No caption
# 1   iambeckyg  16754881  Very proud moment today. So committed to My 🍑 ...
# 2   iambeckyg  16754881  I just announced my Album ESQUINAS y me siento...
# 3   iambeckyg  16754881                            Thank you Taylor Swift.
# 4   iambeckyg  16754881                                         No caption
# 5   iambeckyg  16754881                                         No caption
# 6   iambeckyg  16754881                                         No caption
# 7   iambeckyg  16754881                               Vamos MEXICOOOOOO 🇲🇽
# 8   iambeckyg  16754881  Hear me out. 2 things. First is that it amazes...
# 9   iambeckyg  16754881                           🇲🇽 VAMOOOSSSSS MEXICO!!!
# 10  iambeckyg  16754881                         Just here chillin, y tu? 🩵
# ...

# %%
memezar_df=func(ti.retrieve_user_id('memezar'))
threads_df=pd.concat([threads_df,memezar_df])
memezar_df
# Out:
#       users     user id                                           captions  \
# 0   memezar  2374691999                       My Spotify wrapped this year
# 1   memezar  2374691999             Morning cold makes me regret waking up
# 2   memezar  2374691999  Me listening to a conversation that's none of ...
# 3   memezar  2374691999  "what time did you go to bed last night?"\n\nM...
# 4   memezar  2374691999  Passwords leaving my memory as soon as I creat...
# 5   memezar  2374691999             Nobody: \n\nWheels on a shopping cart:
# 6   memezar  2374691999         Me overthinking about how I'm overthinking
# 7   memezar  2374691999  “My daughter used markers to put\n"makeup" on ...
# 8   memezar  2374691999  The word 'nun' is just the letter n\ndoing a c...
# 9   memezar  2374691999  When you realize Captain America's suit doesn'...
# 10  memezar  2374691999  Friend: You laugh at the dumbest things\n\nMe:...
# ...

# %%
choquei_df=func(ti.retrieve_user_id('choquei'))
threads_df=pd.concat([threads_df,choquei_df])
choquei_df
# Out:
#       users     user id                                           captions  \
# 0   choquei  1555149162  🚨VEJA: Elon Musk colocou oficialmente o logoti...
# 1   choquei  1555149162  🚨FAMOSOS: Fábio Júnior compartilha semelhanças...
# 2   choquei  1555149162  🚨VEJA: Mulher descobre traição de jeito inusit...
# 3   choquei  1555149162  🚨CIÊNCIA: Fazer sexo ajuda a desentupir o nari...
# 4   choquei  1555149162  🚨AGORA: Whindersson Nunes perde a luta de boxe...
# 5   choquei  1555149162  🚨FAMOSOS: Em comemoração aos 2 anos do baby Cr...
# 6   choquei  1555149162                                     DESCE AGORA! 🚗
# 7   choquei  1555149162           🚨DEBATE: Vocês colocam ketchup na pizza?
# 8   choquei  1555149162  🚨VEJA: Virgínia se pronuncia sobre comentário ...
# 9   choquei  1555149162        O vídeo mais fofo que você vai ver hoje! ❤️
# 10  choquei  1555149162  🚨VEJA: Museu de miniaturas na Alemanha retrata...
# ...

# %%
jr10_df=func(ti.retrieve_user_id('jamesrodriguez10'))
threads_df=pd.concat([threads_df,jr10_df])
jr10_df
# Out:
#                users    user id  \
# 0   jamesrodriguez10  188222091
# 1   jamesrodriguez10  188222091
# 2   jamesrodriguez10  188222091
# 3   jamesrodriguez10  188222091
# 4   jamesrodriguez10  188222091
# 5   jamesrodriguez10  188222091
# 6   jamesrodriguez10  188222091
# 7   jamesrodriguez10  188222091
# 8   jamesrodriguez10  188222091
# 9   jamesrodriguez10  188222091
# 10  jamesrodriguez10  188222091
# 11  jamesrodriguez10  188222091
# 12  jamesrodriguez10  188222091
# 13  jamesrodriguez10  188222091
# 14  jamesrodriguez10  188222091
# 15  jamesrodriguez10  188222091
# 16  jamesrodriguez10  188222091
# 17  jamesrodriguez10  188222091
# 18  jamesrodriguez10  188222091
# 19  jamesrodriguez10  188222091
# 20  jamesrodriguez10  188222091
# 21  jamesrodriguez10  188222091
# 22  jamesrodriguez10  188222091
#
#                                              captions  Verified  Likes  \
# 0                                2024 más y mejor. 🇨🇴      True   1796
# ...

# %%
threads_df
# Out:
#                users    user id  \
# 0          instagram   25025320
# 1          instagram   25025320
# 2          instagram   25025320
# 3          instagram   25025320
# 4          instagram   25025320
# ..               ...        ...
# 18  jamesrodriguez10  188222091
# 19  jamesrodriguez10  188222091
# 20  jamesrodriguez10  188222091
# 21  jamesrodriguez10  188222091
# 22  jamesrodriguez10  188222091
#
#                                              captions  Verified  Likes  \
# 0   favorite holiday drink that gives you all the ...      True   3271
# 1   “The universe needs a different version of you...      True   1789
# 2   hiii from the @meowparlour — part cat café, pa...      True   8044
# 3        so how do we *really* feel about fruit cake?      True   2349
# 4                            update: did it anyways 🤭      True   3032
# ..                                                ...       ...    ...
# 18                                              32 👌🏼      True   3081
# ...

# %%
threads_df.to_csv('Top100.csv', index=False)
